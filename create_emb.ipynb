# %%
import warnings
warnings.filterwarnings('ignore')
import pickle
import numpy as np
import pandas as pd
import json
from textblob import TextBlob
import nltk
from scipy import spatial
import torch
import spacy
en_nlp = spacy.load('en')

# %% [markdown]
# ## Convert Json to Pandas Dataframe

# %%
# read data
train = pd.read_json("data/train-v1.1.json")

valid = pd.read_json("data/dev-v1.1.json")

# %%
# construct relative table
# to save time, use only 1% of orginial data 
contexts = []
questions = []
answers_text = []
answers_start = []
for i in range((int)(train.shape[0]/100)):
    topic = train.iloc[i,0]['paragraphs']
    for sub_para in topic:
        for q_a in sub_para['qas']:
            questions.append(q_a['question'])
            answers_start.append(q_a['answers'][0]['answer_start'])
            answers_text.append(q_a['answers'][0]['text'])
            contexts.append(sub_para['context'])   
df = pd.DataFrame({"context":contexts, "question": questions, "answer_start": answers_start, "text": answers_text})

# %%
# df.to_csv("data/train.csv", index = None)

# %% [markdown]
# ## Create dictionary of sentence embeddings for faster computation (To save time now I only use the first 1% of original data)

# %%
# number of paragraphs
paras = list(df["context"].drop_duplicates().reset_index(drop= True))

# %%
len(paras)
# Out:
# 191

# %%
# use blob to separate sentence
blob = TextBlob(" ".join(paras))
sentences = [item.raw for item in blob.sentences]

# %%
# use infersent to encode sentence
infersent = torch.load('InferSent/encoder/infersent.allnli.pickle', map_location=lambda storage, loc: storage)
infersent.set_glove_path("InferSent/dataset/GloVe/glove.840B.300d.txt")
# infersent.set_w2v_path("InferSent/dataset/wiki-news-300d-1M.vec")

# %%
infersent.build_vocab(sentences, tokenize=True)
# Out:
# Found 5871(/6007) words with glove vectors
# Vocab size : 5871

# %%
dict_embeddings
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-9325125ef074> in <module>()
# ----> 1 dict_embeddings
#
# NameError: name 'dict_embeddings' is not defined

# %%
# create sentence embedding
dict_embeddings = {}
for i in range(len(sentences)):
    if (i % 100 == 0):
        print(i)
    dict_embeddings[sentences[i]] = infersent.encode([sentences[i]], tokenize=True)
# Out:
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-eb521857e2dc> in <module>()
#       4     if (i % 100 == 0):
#       5         print(i)
# ----> 6     dict_embeddings[sentences[i]] = infersent.encode([sentences[i]], tokenize=True)
#
# ~/CSCE638Project/models.py in encode(self, sentences, bsize, tokenize, verbose)
#     210                 batch = batch.cuda()
#     211             batch = self.forward(
# --> 212                 (batch, lengths[stidx:stidx + bsize])).data.cpu().numpy()
#     213             embeddings.append(batch)
#     214         embeddings = np.vstack(embeddings)
#
# ~/CSCE638Project/models.py in forward(self, sent_tuple)
#      53         # Handling padding in Recurrent Networks
#      54         sent_packed = nn.utils.rnn.pack_padded_sequence(sent, sent_len)
# ---> 55         sent_output = self.enc_lstm(sent_packed)[0]  # seqlen x batch x 2*nhid
#      56         sent_output = nn.utils.rnn.pad_packed_sequence(sent_output)[0]
#      57
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     190             flat_weight=flat_weight
#     191         )
# --> 192         output, hidden = func(input, self.all_weights, hx, batch_sizes)
#     193         if is_packed:
#     194             output = PackedSequence(output, batch_sizes)
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/_functions/rnn.py in forward(input, *fargs, **fkwargs)
#     322             func = decorator(func)
#     323
# --> 324         return func(input, *fargs, **fkwargs)
#     325
#     326     return forward
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/_functions/rnn.py in forward(input, weight, hidden, batch_sizes)
#     242             input = input.transpose(0, 1)
#     243
# --> 244         nexth, output = func(input, hidden, weight, batch_sizes)
#     245
#     246         if batch_first and not variable_length:
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/_functions/rnn.py in forward(input, hidden, weight, batch_sizes)
#      85                 l = i * num_directions + j
#      86
# ---> 87                 hy, output = inner(input, hidden[l], weight[l], batch_sizes)
#      88                 next_hidden.append(hy)
#      89                 all_output.append(output)
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/_functions/rnn.py in forward(input, hidden, weight, batch_sizes)
#     144         if flat_hidden:
#     145             hidden = (hidden,)
# --> 146         for batch_size in batch_sizes:
#     147             step_input = input[input_offset:input_offset + batch_size]
#     148             input_offset += batch_size
#
# ~/anaconda3/lib/python3.6/site-packages/torch/tensor.py in <lambda>(i)
#     380         if self.dim() == 0:
#     381             raise TypeError('iteration over a 0-d tensor')
# --> 382         return iter(imap(lambda i: self[i], range(self.size(0))))
#     383
#     384     def __hash__(self):
#
# KeyboardInterrupt:

# %%
questions = list(df["question"])

# %%
len(questions)
# Out:
# 1314

# %%
# create question embedding
for i in range(len(questions)):
    if (i % 100 == 0):
        print(i)
    dict_embeddings[questions[i]] = infersent.encode([questions[i]], tokenize=True)
# Out:
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-c3929f9ef185> in <module>()
#       3     if (i % 100 == 0):
#       4         print(i)
# ----> 5     dict_embeddings[questions[i]] = infersent.encode([questions[i]], tokenize=True)
#
# ~/CSCE638Project/models.py in encode(self, sentences, bsize, tokenize, verbose)
#     210                 batch = batch.cuda()
#     211             batch = self.forward(
# --> 212                 (batch, lengths[stidx:stidx + bsize])).data.cpu().numpy()
#     213             embeddings.append(batch)
#     214         embeddings = np.vstack(embeddings)
#
# ~/CSCE638Project/models.py in forward(self, sent_tuple)
#      53         # Handling padding in Recurrent Networks
#      54         sent_packed = nn.utils.rnn.pack_padded_sequence(sent, sent_len)
# ---> 55         sent_output = self.enc_lstm(sent_packed)[0]  # seqlen x batch x 2*nhid
#      56         sent_output = nn.utils.rnn.pad_packed_sequence(sent_output)[0]
#      57
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     190             flat_weight=flat_weight
#     191         )
# --> 192         output, hidden = func(input, self.all_weights, hx, batch_sizes)
#     193         if is_packed:
#     194             output = PackedSequence(output, batch_sizes)
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/_functions/rnn.py in forward(input, *fargs, **fkwargs)
#     322             func = decorator(func)
#     323
# --> 324         return func(input, *fargs, **fkwargs)
#     325
#     326     return forward
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/_functions/rnn.py in forward(input, weight, hidden, batch_sizes)
#     242             input = input.transpose(0, 1)
#     243
# --> 244         nexth, output = func(input, hidden, weight, batch_sizes)
#     245
#     246         if batch_first and not variable_length:
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/_functions/rnn.py in forward(input, hidden, weight, batch_sizes)
#      85                 l = i * num_directions + j
#      86
# ---> 87                 hy, output = inner(input, hidden[l], weight[l], batch_sizes)
#      88                 next_hidden.append(hy)
#      89                 all_output.append(output)
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/_functions/rnn.py in forward(input, hidden, weight, batch_sizes)
#     198                 hidden = (inner(step_input, hidden[0], *weight),)
#     199             else:
# --> 200                 hidden = inner(step_input, hidden, *weight)
#     201             output.append(hidden[0])
#     202
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/_functions/rnn.py in LSTMCell(input, hidden, w_ih, w_hh, b_ih, b_hh)
#      32
#      33     hx, cx = hidden
# ---> 34     gates = F.linear(input, w_ih, b_ih) + F.linear(hx, w_hh, b_hh)
#      35
#      36     ingate, forgetgate, cellgate, outgate = gates.chunk(4, 1)
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1022     if input.dim() == 2 and bias is not None:
#    1023         # fused op is marginally faster
# -> 1024         return torch.addmm(bias, input, weight.t())
#    1025
#    1026     output = input.matmul(weight.t())
#
# KeyboardInterrupt:

# %%
dict_embeddings[df["question"][0]][0]
# Out:
# array([ 0.1095634 ,  0.1142294 ,  0.04428943, ...,  0.02811733,
#        -0.01866924,  0.12806854], dtype=float32)

# %%
# use d1 and d2 as train and test set
d1 = {key:dict_embeddings[key] for i, key in enumerate(dict_embeddings) if i % 2 == 0}
d2 = {key:dict_embeddings[key] for i, key in enumerate(dict_embeddings) if i % 2 == 1}

# %%
d1
# Out:
# {'Architecturally, the school has a Catholic character.': array([[ 0.05519996,  0.05013141,  0.04787038, ...,  0.00821209,
#          -0.03642813,  0.044685  ]], dtype=float32),
#  'Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes".': array([[0.11262652, 0.11146841, 0.14750297, ..., 0.00293285, 0.03322018,
#          0.06657628]], dtype=float32),
#  'Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection.': array([[ 0.04149357,  0.0703306 ,  0.03724371, ...,  0.01096805,
#          -0.02892281,  0.0428066 ]], dtype=float32),
#  'At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary.': array([[ 0.04795522,  0.16508998,  0.09383532, ...,  0.05321149,
#          -0.01826634,  0.10806957]], dtype=float32),
#  'The nine student-run outlets include three newspapers, both a radio and television station, and several magazines and journals.': array([[ 0.0763403 ,  0.19636494,  0.05593642, ...,  0.2378396 ,
#          -0.02239182,  0.01162959]], dtype=float32),
#  'The other magazine, The Juggler, is released twice a year and focuses on student literature and artwork.': array([[ 0.08742335,  0.10380536,  0.0770895 , ...,  0.08384255,
#           0.01738949, -0.00992417]], dtype=float32),
#  "The newspapers have varying publication interests, with The Observer published daily and mainly reporting university and other news, and staffed by students from both Notre Dame and Saint Mary's College.": array([[0.06485783, 0.08233328, 0.08718017, ..., 0.05962595, 0.01010794,
#          0.14499184]], dtype=float32),
#  'In 1987, when some students believed that The Observer began to show a conservative bias, a liberal newspaper, Common Sense was published.': array([[ 0.07516038,  0.1238085 ,  0.12083028, ...,  0.07708558,
#          -0.01160982,  0.08446363]], dtype=float32),
#  'Neither paper is published as often as The Observer; however, all three are distributed to all students.': array([[0.03942868, 0.15866904, 0.10985931, ..., 0.16448529, 0.00729141,
#          0.00840559]], dtype=float32),
#  'The university is the major seat of the Congregation of Holy Cross (albeit not its official headquarters, which are in Rome).': array([[ 0.07278652,  0.11468702,  0.03656113, ...,  0.05688497,
#          -0.03116411,  0.00473161]], dtype=float32),
#  'Old College, the oldest building on campus and located near the shore of St. Mary lake, houses undergraduate seminarians.': array([[0.06044032, 0.09268326, 0.0654119 , ..., 0.13195021, 0.03364472,
#          0.16120541]], dtype=float32),
#  'The university through the Moreau Seminary has ties to theologian Frederick Buechner.': array([[ 0.02968155,  0.04242778,  0.10886519, ..., -0.02026402,
#           0.02344681,  0.12567647]], dtype=float32),
#  'The College of Engineering was established in 1920, however, early courses in civil and mechanical engineering were a part of the College of Science since the 1870s.': array([[ 0.04502603,  0.15410224,  0.05160062, ...,  0.03524945,
#          -0.00729064,  0.07529826]], dtype=float32),
#  'degrees offered.': array([[ 0.04480024,  0.05662298,  0.02129079, ...,  0.09963822,
#          -0.03814263, -0.01640047]], dtype=float32),
#  'and Master of Business Administration (MBA) degrees, respectively.': array([[0.01777024, 0.12380433, 0.01010439, ..., 0.07100284, 0.02564826,
#          0.02135007]], dtype=float32),
#  'The First Year of Studies program was established in 1962 to guide incoming freshmen in their first year at the school before they have declared a major.': array([[0.03122488, 0.18650761, 0.05387028, ..., 0.15741895, 0.02472224,
#          0.0839507 ]], dtype=float32),
#  'The program also includes a Learning Resource Center which provides time management, collaborative learning, and subject tutoring.': array([[-0.00554873,  0.10406447,  0.0069708 , ...,  0.11587694,
#           0.00421066,  0.10319481]], dtype=float32),
#  'The university first offered graduate degrees, in the form of a Master of Arts (MA), in the 1854–1855 academic year.': array([[0.045502  , 0.12919986, 0.05056107, ..., 0.04863533, 0.02732492,
#          0.04931976]], dtype=float32),
#  'and Master of Civil Engineering in its early stages of growth, before a formal graduate school education was developed with a thesis not required to receive the degrees.': array([[0.05193595, 0.11927973, 0.0477569 , ..., 0.09516005, 0.02647279,
#          0.04782446]], dtype=float32),
#  'Today each of the five colleges offer graduate education.': array([[ 0.06414087,  0.21115416, -0.01034122, ...,  0.22990014,
#           0.02527619,  0.02506495]], dtype=float32),
#  'program also exists.': array([[ 0.04067935,  0.03077514,  0.01307912, ...,  0.00471408,
#          -0.03814263, -0.02892259]], dtype=float32),
#  'The School of Architecture offers a Master of Architecture, while each of the departments of the College of Engineering offer PhD programs.': array([[ 0.00763994,  0.11477694, -0.01341369, ...,  0.08043291,
#           0.05167384,  0.06804904]], dtype=float32),
#  'It also operates facilities in Chicago and Cincinnati for its executive MBA program.': array([[0.10178053, 0.09505498, 0.02449926, ..., 0.08506835, 0.03748374,
#          0.03113682]], dtype=float32),
#  'The Joan B. Kroc Institute for International Peace Studies at the University of Notre Dame is dedicated to research, education and outreach on the causes of violent conflict and the conditions for sustainable peace.': array([[0.00491565, 0.15959986, 0.14992826, ..., 0.00735425, 0.03324759,
#          0.13503261]], dtype=float32),
#  "It was founded in 1986 through the donations of Joan B. Kroc, the widow of McDonald's owner Ray Kroc.": array([[ 0.09270079,  0.10632651, -0.0041974 , ...,  0.0195431 ,
#          -0.03814263,  0.15177758]], dtype=float32),
#  'Theodore M. Hesburgh CSC, President Emeritus of the University of Notre Dame.': array([[-0.00157887,  0.12160839, -0.00887386, ..., -0.02259157,
#           0.01944311,  0.11931754]], dtype=float32),
#  'The library system of the university is divided between the main library and each of the colleges and schools.': array([[0.02319574, 0.07313912, 0.03793756, ..., 0.12563084, 0.02084117,
#          0.00814482]], dtype=float32),
#  'The front of the library is adorned with the Word of Life mural designed by artist Millard Sheets.': array([[ 0.00594058,  0.09668281,  0.06735709, ...,  0.03314231,
#          -0.018766  ,  0.1581716 ]], dtype=float32),
#  'Notre Dame is known for its competitive admissions, with the incoming class enrolling in fall 2015 admitting 3,577 from a pool of 18,156 (19.7%).': array([[ 0.07246337,  0.07173795,  0.04527427, ...,  0.10270818,
#          -0.01503533,  0.03460968]], dtype=float32),
#  'The university practices a non-restrictive early action policy that allows admitted students to consider admission to Notre Dame as well as any other colleges to which they were accepted.': array([[ 0.02312845,  0.03050468,  0.03424086, ..., -0.00335152,
#           0.03477871,  0.06035165]], dtype=float32),
#  'Admitted students came from 1,311 high schools and the average student traveled more than 750 miles to Notre Dame, making it arguably the most representative university in the United States.': array([[0.11379509, 0.12336062, 0.07797385, ..., 0.05346088, 0.02681104,
#          0.04457844]], dtype=float32),
#  'In 2015-2016, Notre Dame ranked 18th overall among "national universities" in the United States in U.S. News & World Report\'s Best Colleges 2016.': array([[0.15094085, 0.20007977, 0.0504428 , ..., 0.02735076, 0.04396175,
#          0.04683554]], dtype=float32),
#  "Forbes.com's America's Best Colleges ranks Notre Dame 13th among colleges in the United States in 2015, 8th among Research Universities, and 1st in the Midwest.": array([[0.142248  , 0.16794795, 0.06124227, ..., 0.02858837, 0.06244816,
#          0.06312037]], dtype=float32),
#  'BusinessWeek ranks Mendoza College of Business undergraduate school as 1st overall.': array([[0.14337096, 0.15227227, 0.03818204, ..., 0.0358067 , 0.03667302,
#          0.05228779]], dtype=float32),
#  "The Philosophical Gourmet Report ranks Notre Dame's graduate philosophy program as 15th nationally, while ARCHITECT Magazine ranked the undergraduate architecture program as 12th nationally.": array([[0.10012443, 0.15471378, 0.04911118, ..., 0.07178259, 0.04940893,
#          0.02199603]], dtype=float32),
#  'According to payscale.com, undergraduate alumni of University of Notre Dame have a mid-career median salary $110,000, making it the 24th highest among colleges and universities in the United States.': array([[0.12527731, 0.13091701, 0.09302544, ..., 0.09275112, 0.02785043,
#          0.09608041]], dtype=float32),
#  'Father Joseph Carrier, C.S.C.': array([[ 0.07044347,  0.02269202, -0.03044511, ..., -0.03926745,
#          -0.03814263,  0.15683354]], dtype=float32),
#  'Carrier taught that scientific research and its promise for progress were not antagonistic to the ideals of intellectual and moral culture endorsed by the Church.': array([[0.08989745, 0.09101576, 0.022363  , ..., 0.05726007, 0.04553449,
#          0.12407976]], dtype=float32),
#  'Zahm was active in the Catholic Summer School movement, which introduced Catholic laity to contemporary intellectual issues.': array([[ 0.07977626,  0.06764638,  0.07392935, ..., -0.03200182,
#          -0.03166096,  0.03962582]], dtype=float32),
#  "The intervention of Irish American Catholics in Rome prevented Zahm's censure by the Vatican.": array([[ 0.10945018,  0.10213292,  0.07667927, ..., -0.02045256,
#          -0.0289892 , -0.02263261]], dtype=float32),
#  "In 1882, Albert Zahm (John Zahm's brother) built an early wind tunnel used to compare lift to drag of aeronautical models.": array([[ 0.06533629,  0.12845865,  0.13129659, ..., -0.00511589,
#           0.04606054,  0.14404236]], dtype=float32),
#  'In 1931, Father Julius Nieuwland performed early work on basic reactions that was used to create neoprene.': array([[0.04438874, 0.07643923, 0.10937126, ..., 0.10580914, 0.01405883,
#          0.10690155]], dtype=float32),
#  'The Lobund Institute grew out of pioneering research in germ-free-life which began in 1928.': array([[0.07576816, 0.16830772, 0.04539931, ..., 0.06755406, 0.0324693 ,
#          0.09709884]], dtype=float32),
#  'Though others had taken up this idea, their research was short lived and inconclusive.': array([[ 0.02245284,  0.0834822 ,  0.1113109 , ...,  0.14167565,
#          -0.00312698,  0.00415643]], dtype=float32),
#  "But the objective was not merely to answer Pasteur's question but also to produce the germ free animal as a new tool for biological and medical research.": array([[0.04496573, 0.07687555, 0.08133471, ..., 0.06272487, 0.03375516,
#          0.06467881]], dtype=float32),
#  'Today the work has spread to other universities.': array([[ 0.08249667,  0.0719115 ,  0.05483204, ...,  0.02258837,
#          -0.01828209,  0.00362032]], dtype=float32),
#  'In the 1940s Lobund achieved independent status as a purely research organization and in 1950 was raised to the status of an Institute.': array([[0.10001208, 0.1768761 , 0.04533406, ..., 0.06269549, 0.01759555,
#          0.03821033]], dtype=float32),
#  'The Review of Politics was founded in 1939 by Gurian, modeled after German Catholic journals.': array([[ 0.07702555,  0.1130866 ,  0.05371564, ...,  0.0410207 ,
#          -0.02398008,  0.0492598 ]], dtype=float32),
#  'For 44 years, the Review was edited by Gurian, Matthew Fitzsimons, Frederick Crosson, and Thomas Stritch.': array([[0.04622583, 0.07481927, 0.01420397, ..., 0.03503812, 0.00440044,
#          0.12752686]], dtype=float32),
#  'It became a major forum for political ideas and modern political concerns, especially from a Catholic and scholastic tradition.': array([[ 0.05263337,  0.11941694,  0.04745629, ...,  0.00446527,
#          -0.03814263,  0.0221031 ]], dtype=float32),
#  'The university president, John Jenkins, described his hope that Notre Dame would become "one of the pre–eminent research institutions in the world" in his inaugural address.': array([[0.12326713, 0.0977983 , 0.05506111, ..., 0.08444195, 0.0486096 ,
#          0.18394242]], dtype=float32),
#  'Recent research includes work on family conflict and child development, genome mapping, the increasing trade deficit of the United States with China, studies in fluid mechanics, computational science and engineering, and marketing trends on the Internet.': array([[0.11936712, 0.1573725 , 0.10199305, ..., 0.12861231, 0.05942537,
#          0.0657244 ]], dtype=float32),
#  'In 2014 the Notre Dame student body consisted of 12,179 students, with 8,448 undergraduates, 2,138 graduate and professional and 1,593 professional (Law, M.Div., Business, M.Ed.)': array([[ 0.03705068,  0.11039677,  0.02012001, ...,  0.14698558,
#          -0.03081384,  0.08194303]], dtype=float32),
#  'Around 21–24% of students are children of alumni, and although 37% of students come from the Midwestern United States, the student body represents all 50 states and 100 countries.': array([[ 0.12653826,  0.13607107,  0.03626509, ...,  0.15351297,
#          -0.03814263,  0.03185251]], dtype=float32),
#  'As of March 2015[update] The Princeton Review ranked Notre Dame as the ninth highest.': array([[0.03490478, 0.19617377, 0.0542535 , ..., 0.03814679, 0.00428658,
#          0.04168702]], dtype=float32),
#  'It has also been commended by some diversity oriented publications; Hispanic Magazine in 2004 ranked the university ninth on its list of the top–25 colleges for Latinos, and The Journal of Blacks in Higher Education recognized the university in 2006 for raising enrollment of African-American students.': array([[0.10203356, 0.16592532, 0.10374355, ..., 0.11683401, 0.04683935,
#          0.02836012]], dtype=float32),
#  "The annual Bookstore Basketball tournament is the largest outdoor five-on-five tournament in the world with over 700 teams participating each year, while the Notre Dame Men's Boxing Club hosts the annual Bengal Bouts tournament that raises money for the Holy Cross Missions in Bangladesh.": array([[ 0.10314629,  0.15749286,  0.08661812, ...,  0.06696513,
#          -0.02467591,  0.07229701]], dtype=float32),
#  'The majority of the graduate students on campus live in one of four graduate housing complexes on campus, while all on-campus undergraduates live in one of the 29 residence halls.': array([[ 0.09939139,  0.19204731,  0.08209208, ...,  0.23482554,
#          -0.03814263,  0.01310081]], dtype=float32),
#  "The university maintains a visiting policy (known as parietal hours) for those students who live in dormitories, specifying times when members of the opposite sex are allowed to visit other students' dorm rooms; however, all residence halls have 24-hour social spaces for students regardless of gender.": array([[ 0.10240328,  0.10101102,  0.06612176, ...,  0.09448373,
#          -0.01614517,  0.07075742]], dtype=float32),
#  'There are no traditional social fraternities or sororities at the university, but a majority of students live in the same residence hall for all four years.': array([[ 0.08423497,  0.14294374,  0.03379435, ...,  0.24587214,
#          -0.03814263,  0.00179473]], dtype=float32),
#  'At the end of the intramural season, the championship game is played on the field in Notre Dame Stadium.': array([[ 0.02185198,  0.11590907,  0.03117987, ..., -0.02617669,
#          -0.03814263,  0.00655255]], dtype=float32),
#  'While religious affiliation is not a criterion for admission, more than 93% of students identify as Christian, with over 80% of the total being Catholic.': array([[ 0.08667263,  0.16816999,  0.06901232, ...,  0.13976803,
#          -0.02001598,  0.0498675 ]], dtype=float32),
#  'There are multitudes of religious statues and artwork around campus, most prominent of which are the statue of Mary on the Main Building, the Notre Dame Grotto, and the Word of Life mural on Hesburgh Library depicting Christ as a teacher.': array([[ 0.04671509,  0.1068984 ,  0.10302085, ...,  0.08724425,
#          -0.00177028,  0.13081446]], dtype=float32),
#  'There are many religious clubs (catholic and non-Catholic) at the school, including Council #1477 of the Knights of Columbus (KOC), Baptist Collegiate Ministry (BCM), Jewish Club, Muslim Student Association, Orthodox Christian Fellowship, The Mormon Club, and many more.': array([[ 0.07406321,  0.12197158,  0.05182875, ...,  0.05954612,
#          -0.01751264,  0.15071674]], dtype=float32),
#  'Fifty-seven chapels are located throughout the campus.': array([[ 0.17639215,  0.03098875,  0.03771722, ...,  0.10414729,
#          -0.03485126, -0.02892259]], dtype=float32),
#  'The university founder, Fr.': array([[ 0.0127414 ,  0.05531799, -0.02357255, ..., -0.02461645,
#          -0.00016945,  0.13235533]], dtype=float32),
#  'William Corby, immediately planned for the rebuilding of the structure that had housed virtually the entire University.': array([[ 0.04766561,  0.1001692 ,  0.04860225, ...,  0.06612152,
#          -0.01856505,  0.13631777]], dtype=float32),
#  'The library collection was also rebuilt and stayed housed in the new Main Building for years afterwards.': array([[0.05722935, 0.01071862, 0.05900256, ..., 0.0748217 , 0.01314372,
#          0.00187233]], dtype=float32),
#  'Eventually becoming known as Washington Hall, it hosted plays and musical acts put on by the school.': array([[ 0.09049717,  0.09544699,  0.06278598, ...,  0.03035333,
#          -0.03814263,  0.08286152]], dtype=float32),
#  'The hall housed multiple classrooms and science labs needed for early research at the university.': array([[0.03432998, 0.0494077 , 0.02196693, ..., 0.18754742, 0.02806684,
#          0.01652777]], dtype=float32),
#  'By contrast, the Jesuit colleges, bastions of academic conservatism, were reluctant to move to a system of electives.': array([[ 0.0697018 ,  0.11385181,  0.04927431, ...,  0.03383255,
#          -0.01478155,  0.00677445]], dtype=float32),
#  'Notre Dame continued to grow over the years, adding more colleges, programs, and sports teams.': array([[ 0.09072165,  0.06869557,  0.01127661, ...,  0.08644156,
#          -0.00416145,  0.04006716]], dtype=float32),
#  'The university continued to expand and add new residence halls and buildings with each subsequent president.': array([[0.03922664, 0.0670174 , 0.07597835, ..., 0.12224372, 0.02716134,
#          0.03297402]], dtype=float32),
#  'Knute Rockne became head coach in 1918.': array([[ 0.06238442,  0.02333307,  0.02631372, ..., -0.03665822,
#          -0.03814263,  0.13593766]], dtype=float32),
#  'During his 13 years the Irish won three national championships, had five undefeated seasons, won the Rose Bowl in 1925, and produced players such as George Gipp and the "Four Horsemen".': array([[ 0.06961318,  0.20247993,  0.043244  , ...,  0.16834092,
#          -0.03814263,  0.13191444]], dtype=float32),
#  "Rockne's offenses employed the Notre Dame Box and his defenses ran a 7–2–2 scheme.": array([[ 0.04438453,  0.05900011, -0.00494241, ...,  0.02782133,
#          -0.00977122,  0.05756728]], dtype=float32),
#  'The success of its football team made Notre Dame a household name.': array([[ 0.02340859,  0.111352  ,  0.05659777, ...,  0.02762228,
#          -0.03814263,  0.01043611]], dtype=float32),
#  'Catholics rallied up around the team and listen to the games on the radio, especially when it knocked off the schools that symbolized the Protestant establishment in America — Harvard, Yale, Princeton, and Army.': array([[ 0.09814402,  0.09312647,  0.09203063, ...,  0.02558598,
#          -0.0141858 ,  0.05136767]], dtype=float32),
#  'The most remarkable episode of violence was the clash between Notre Dame students and the Ku Klux Klan in 1924.': array([[ 0.09318785,  0.11838112,  0.12289949, ...,  0.03206408,
#          -0.03814263,  0.01653099]], dtype=float32),
#  'The Klan decided to have a week-long Klavern in South Bend.': array([[ 0.13731182,  0.14490257,  0.09990554, ...,  0.04520702,
#          -0.03814263,  0.00481425]], dtype=float32),
#  'On May 19 thousands of students massed downtown protesting the Klavern, and only the arrival of college president Fr.': array([[ 0.05369664,  0.1228998 ,  0.05737971, ...,  0.07180154,
#          -0.03814263,  0.06851366]], dtype=float32),
#  'The next day, football coach Knute Rockne spoke at a campus rally and implored the students to obey the college president and refrain from further violence.': array([[ 0.03718692,  0.01444804,  0.10517573, ..., -0.01520468,
#           0.03499927,  0.12885612]], dtype=float32),
#  "Holy Cross Father John Francis O'Hara was elected vice-president in 1933 and president of Notre Dame in 1934.": array([[ 0.07529586,  0.07779213, -0.00259152, ..., -0.03926745,
#          -0.03814263,  0.18044254]], dtype=float32),
#  'O\'Hara strongly believed that the Fighting Irish football team could be an effective means to "acquaint the public with the ideals that dominate" Notre Dame.': array([[ 0.08753174,  0.04574158,  0.03526098, ..., -0.01836056,
#          -0.03814263,  0.01890908]], dtype=float32),
#  'When St. Paul said: \'Whether you eat or drink, or whatsoever else you do, do all for the glory of God,\' he included football."': array([[ 0.03946402,  0.08900145,  0.03528202, ..., -0.01926814,
#          -0.03814263,  0.19004428]], dtype=float32),
#  'John J. Cavanaugh, C.S.C.': array([[-0.00574629,  0.14667667, -0.03044511, ..., -0.03926745,
#          -0.03814263,  0.19310284]], dtype=float32),
#  "Cavanaugh's legacy at Notre Dame in the post-war years was devoted to raising academic standards and reshaping the university administration to suit it to an enlarged educational mission and an expanded student body and stressing advanced studies and research at a time when Notre Dame quadrupled in student census, undergraduate enrollment increased by more than half, and graduate student enrollment grew fivefold.": array([[0.06628988, 0.08362787, 0.08279013, ..., 0.10726775, 0.05806787,
#          0.06991013]], dtype=float32),
#  "Cavanaugh also presided over the construction of the Nieuwland Science Hall, Fisher Hall, and the Morris Inn, as well as the Hall of Liberal Arts (now O'Shaughnessy Hall), made possible by a donation from I.A.": array([[ 0.04595503,  0.1232978 ,  0.1009865 , ...,  0.04572712,
#          -0.02865582,  0.16191229]], dtype=float32),
#  "Cavanaugh also established a system of advisory councils at the university, which continue today and are vital to the university's governance and development The Rev.": array([[0.04595503, 0.10258488, 0.04686427, ..., 0.0309673 , 0.05985694,
#          0.06601262]], dtype=float32),
#  'In that time the annual operating budget rose by a factor of 18 from $9.7 million to $176.6 million, and the endowment by a factor of 40 from $9 million to $350 million, and research funding by a factor of 20 from $735,000 to $15 million.': array([[ 0.04826041,  0.1886229 ,  0.03553124, ...,  0.11674661,
#           0.04356272, -0.00704563]], dtype=float32),
#  'Hesburgh is also credited with transforming the face of Notre Dame by making it a coeducational institution.': array([[ 0.02609211,  0.08046848,  0.143693  , ...,  0.05297575,
#          -0.02510331,  0.02986346]], dtype=float32),
#  "After extensive debate, merging with St. Mary's was rejected, primarily because of the differential in faculty qualifications and pay scales.": array([[0.02409964, 0.136832  , 0.04389085, ..., 0.05426139, 0.0326805 ,
#          0.13523485]], dtype=float32),
#  'Charles E. Sheedy, C.S.C., Notre Dame\'s Dean of Arts and Letters, "certain features formerly considered advantageous and enviable are now seen as anachronistic and out of place....': array([[ 0.05786466,  0.15514098,  0.09788281, ..., -0.00043127,
#          -0.03814263,  0.13067088]], dtype=float32),
#  'Thomas Blantz, C.S.C., Notre Dame\'s Vice President of Student Affairs, added that coeducation "opened up a whole other pool of very bright students."': array([[ 0.02745379,  0.12372221,  0.04182262, ...,  0.03305589,
#          -0.01040768,  0.07742356]], dtype=float32),
#  "In 1971 Mary Ann Proctor became the first female undergraduate; she transferred from St. Mary's College.": array([[ 0.03705068,  0.11178502,  0.07861967, ...,  0.0693962 ,
#          -0.01388269,  0.21451578]], dtype=float32),
#  "In the 18 years under the presidency of Edward Malloy, C.S.C., (1987–2005), there was a rapid growth in the school's reputation, faculty, and resources.": array([[ 0.04404324,  0.13402694,  0.10764703, ...,  0.05976071,
#          -0.01476827,  0.10277351]], dtype=float32),
#  "Notre Dame's most recent[when?]": array([[ 0.0906629 ,  0.09947612,  0.09220619, ...,  0.03963047,
#          -0.02794202,  0.03672643]], dtype=float32),
#  'Since 2005, Notre Dame has been led by John I. Jenkins, C.S.C., the 17th president of the university.': array([[0.0404441 , 0.095495  , 0.01259197, ..., 0.03136386, 0.00311096,
#          0.17661001]], dtype=float32),
#  'In his inaugural address, Jenkins described his goals of making the university a leader in research that recognizes ethics and building the connection between faith and studies.': array([[0.06378294, 0.1306488 , 0.08527954, ..., 0.07150799, 0.02953757,
#          0.13595293]], dtype=float32),
#  'Because of its Catholic identity, a number of religious buildings stand on campus.': array([[0.05722636, 0.13055988, 0.05298644, ..., 0.11166283, 0.03696995,
#          0.01925735]], dtype=float32),
#  'The current Basilica of the Sacred Heart is located on the spot of Fr.': array([[ 0.09984551,  0.14302188,  0.10856694, ...,  0.00272749,
#          -0.03814263,  0.05829942]], dtype=float32),
#  'It is built in French Revival style and it is decorated by stained glass windows imported directly from France.': array([[0.10907759, 0.04611835, 0.13449657, ..., 0.04401606, 0.11288427,
#          0.01488748]], dtype=float32),
#  'Sorin to be artist in residence.': array([[ 0.10991665,  0.05423281,  0.08531046, ...,  0.01654149,
#          -0.03814263,  0.04430525]], dtype=float32),
#  'Inside the church there are also sculptures by Ivan Mestrovic.': array([[ 0.05976341,  0.04885127,  0.06048357, ...,  0.01434535,
#          -0.03814263,  0.05987385]], dtype=float32),
#  'It is very popular among students and alumni as a place of prayer and meditation, and it is considered one of the most beloved spots on campus.': array([[ 0.09462505,  0.10165696,  0.0949967 , ...,  0.08193714,
#          -0.03485126,  0.01770515]], dtype=float32),
#  'Zahm, but in 1950 it was converted to a student union building and named LaFortune Center, after Joseph LaFortune, an oil executive from Tulsa, Oklahoma.': array([[ 0.08177146,  0.15582435,  0.03696782, ...,  0.06963811,
#          -0.01669126,  0.15675707]], dtype=float32),
#  'LaFortune employs 35 part-time student staff and 29 full-time non-student staff and has an annual budget of $1.2 million.': array([[ 0.0403248 ,  0.14585489,  0.0106313 , ...,  0.09887439,
#           0.00852935, -0.02329748]], dtype=float32),
#  'The building also houses restaurants from national restaurant chains.': array([[ 0.08077809,  0.07208826,  0.05628067, ...,  0.15403861,
#          -0.03743326, -0.02892259]], dtype=float32),
#  'Over the years 29 residence halls have been built to accommodate students and each has been constructed with its own chapel.': array([[ 0.05005431,  0.05712704,  0.11665935, ...,  0.13353989,
#           0.00157999, -0.00450821]], dtype=float32),
#  'Since 2004, several buildings have been added, including the DeBartolo Performing Arts Center, the Guglielmino Complex, and the Jordan Hall of Science.': array([[ 0.01875201,  0.13774066,  0.09558725, ...,  0.17167172,
#          -0.00333522,  0.11731485]], dtype=float32),
#  'Ryan Hall was completed and began housing undergraduate women in the fall of 2009.': array([[0.05689478, 0.10946009, 0.12610361, ..., 0.05823345, 0.03336321,
#          0.13079831]], dtype=float32),
#  'Additionally the new hockey arena opened in the fall of 2011.': array([[ 0.0798237 ,  0.09514542,  0.0467474 , ..., -0.02603403,
#          -0.03814263, -0.00945964]], dtype=float32),
#  'Because of its long athletic tradition, the university features also many building dedicated to sport.': array([[0.05722636, 0.08901186, 0.04687293, ..., 0.05406789, 0.00293159,
#          0.00222123]], dtype=float32),
#  'Prominent venues include also the Edmund P. Joyce Center, with indoor basketball and volleyball courts, and the Compton Family Ice Arena, a two-rink facility dedicated to hockey.': array([[ 0.14396179,  0.11110727,  0.03917318, ...,  0.05229664,
#          -0.01641087,  0.13079669]], dtype=float32),
#  'The University of Notre Dame has made being a sustainability leader an integral part of its mission, creating the Office of Sustainability in 2008 to achieve a number of goals in the areas of power generation, design and construction, waste reduction, procurement, food services, transportation, and water.As of 2012[update] four building construction projects were pursuing LEED-Certified status and three were pursuing LEED Silver.': array([[0.04762884, 0.24251941, 0.10410906, ..., 0.25449905, 0.06469659,
#          0.10028654]], dtype=float32),
#  'On the Sustainable Endowments Institute\'s College Sustainability Report Card 2010, University of Notre Dame received a "B" grade.': array([[0.0435826 , 0.2385103 , 0.03488218, ..., 0.07359324, 0.0943097 ,
#          0.10261004]], dtype=float32),
#  'Father Gustavo Gutierrez, the founder of Liberation Theology is a current faculty member.': array([[ 0.02769232,  0.1302357 ,  0.05261884, ...,  0.03123911,
#          -0.01376455,  0.0960346 ]], dtype=float32),
#  'The university has had a presence in London, England, since 1968.': array([[ 0.07302903,  0.06599057,  0.09734405, ...,  0.01008568,
#          -0.01238933,  0.02940529]], dtype=float32),
#  'The center enables the Colleges of Arts & Letters, Business Administration, Science, Engineering and the Law School to develop their own programs in London, as well as hosting conferences and symposia.': array([[0.07084555, 0.12876026, 0.10170602, ..., 0.1664069 , 0.02208517,
#          0.07505365]], dtype=float32),
#  "The College of Arts and Letters was established as the university's first college in 1842 with the first degrees given in 1849.": array([[ 0.03039647,  0.15400952,  0.05591566, ...,  0.140892  ,
#          -0.00693203,  0.07052769]], dtype=float32),
#  "Today the college, housed in O'Shaughnessy Hall, includes 20 departments in the areas of fine arts, humanities, and social sciences, and awards Bachelor of Arts (B.A.)": array([[ 0.08357788,  0.1458469 ,  0.06891408, ...,  0.16865626,
#          -0.01000722,  0.11917339]], dtype=float32),
#  'There are around 2,500 undergraduates and 750 graduates enrolled in the college.': array([[ 0.08195498,  0.15681161,  0.0167476 , ...,  0.06208562,
#          -0.00977141,  0.06454386]], dtype=float32),
#  "Dillon's scientific courses were six years of work, including higher-level mathematics courses.": array([[0.03502585, 0.18407854, 0.02518907, ..., 0.25739273, 0.01711974,
#          0.03671477]], dtype=float32),
#  'degrees.': array([[ 0.04480024,  0.00604423,  0.02440534, ...,  0.09486773,
#          -0.03814263, -0.02892259]], dtype=float32),
#  'The School of Architecture was established in 1899, although degrees in architecture were first awarded by the university in 1898.': array([[0.04464353, 0.10601553, 0.034433  , ..., 0.10961446, 0.0173883 ,
#          0.02240717]], dtype=float32),
#  'All undergraduate students study the third year of the program in Rome.': array([[0.04947174, 0.11963794, 0.04347572, ..., 0.10445618, 0.06280056,
#          0.07264093]], dtype=float32),
#  'following the principles of New Urbanism and New Classical Architecture).': array([[ 0.04753645,  0.12253737,  0.05954218, ...,  0.11044584,
#          -0.00561701,  0.10285145]], dtype=float32),
#  "The library system also includes branch libraries for Architecture, Chemistry & Physics, Engineering, Law, and Mathematics as well as information centers in the Mendoza College of Business, the Kellogg Institute for International Studies, the Joan B. Kroc Institute for International Peace Studies, and a slide library in O'Shaughnessy Hall.": array([[0.06209683, 0.17763332, 0.02417385, ..., 0.15959334, 0.05454933,
#          0.13554242]], dtype=float32),
#  'Located on the first floor of Stanford Hall, it is the first branch of the library system to be housed in a dorm room.': array([[0.11903809, 0.16963288, 0.06847876, ..., 0.03597062, 0.0232357 ,
#          0.14679468]], dtype=float32),
#  "The rise of Hitler and other dictators in the 1930s forced numerous Catholic intellectuals to flee Europe; president John O'Hara brought many to Notre Dame.": array([[ 0.1698554 ,  0.13323505,  0.0975434 , ...,  0.01055769,
#          -0.03814263,  0.1499743 ]], dtype=float32),
#  'Positivism dominated American intellectual life in the 1920s onward but in marked contrast, Gurian received a German Catholic education and wrote his doctoral dissertation under Max Scheler.': array([[0.12102336, 0.0688427 , 0.09977965, ..., 0.13869755, 0.06462611,
#          0.03899584]], dtype=float32),
#  'Yves Simon (1903–61), brought to ND in the 1940s the insights of French studies in the Aristotelian-Thomistic tradition of philosophy; his own teacher Jacques Maritain (1882–73) was a frequent visitor to campus.': array([[ 0.08488224,  0.0910203 ,  0.10764332, ...,  0.08862627,
#          -0.00233685,  0.11573289]], dtype=float32),
#  'In French, Notre Dame du Lac means "Our Lady of the Lake" and refers to the university\'s patron saint, the Virgin Mary.': array([[0.08566925, 0.10629866, 0.06410199, ..., 0.02157951, 0.00762775,
#          0.11712852]], dtype=float32),
#  'Notre Dame rose to national prominence in the early 1900s for its Fighting Irish football team, especially under the guidance of the legendary coach Knute Rockne.': array([[ 0.12885773,  0.08514974,  0.07221476, ...,  0.02857234,
#          -0.03814263,  0.08383398]], dtype=float32),
#  'The football team, an Independent, has accumulated eleven consensus national championships, seven Heisman Trophy winners, 62 members in the College Football Hall of Fame and 13 members in the Pro Football Hall of Fame and is considered one of the most famed and successful college football teams in history.': array([[ 0.0663752 ,  0.19713879,  0.06824927, ...,  0.16856214,
#          -0.03814263,  0.09260233]], dtype=float32),
#  'The Notre Dame Victory March is often regarded as the most famous and recognizable collegiate fight song.': array([[ 0.08595012,  0.1660006 ,  0.14098103, ...,  0.02384492,
#          -0.03814263, -0.00572921]], dtype=float32),
#  'The undergraduate component of the university is organized into four colleges (Arts and Letters, Science, Engineering, Business) and the Architecture School.': array([[-0.00144108,  0.18330744,  0.04444582, ...,  0.21005575,
#           0.01814017,  0.05423383]], dtype=float32),
#  "Notre Dame's graduate program has more than 50 master's, doctoral and professional degree programs offered by the five schools, with the addition of the Notre Dame Law School and a MD-PhD program offered in combination with IU medical School.": array([[0.03254578, 0.16876405, 0.04888605, ..., 0.21462606, 0.04139758,
#          0.0623951 ]], dtype=float32),
#  "Over 80% of the university's 8,000 undergraduates live on campus in one of 29 single-sex residence halls, each with its own traditions, legacies, events and intramural sports teams.": array([[ 0.09161095,  0.15348601,  0.04620624, ...,  0.1576165 ,
#          -0.02944708,  0.00558726]], dtype=float32),
#  'In 1842, the Bishop of Vincennes, Célestine Guynemer de la Hailandière, offered land to Father Edward Sorin of the Congregation of the Holy Cross, on the condition that he build a college in two years.': array([[ 0.05432781,  0.12632932,  0.09243622, ...,  0.2049277 ,
#          -0.01930606,  0.13982002]], dtype=float32),
#  "Sorin arrived on the site with eight Holy Cross brothers from France and Ireland on November 26, 1842, and began the school using Father Stephen Badin's old log chapel.": array([[ 0.11517093,  0.16167796,  0.08808653, ...,  0.18054274,
#          -0.00747661,  0.12763408]], dtype=float32),
#  'They immediately acquired two students and set about building additions to the campus.': array([[0.05523064, 0.11214824, 0.12331263, ..., 0.17456324, 0.05369557,
#          0.0340117 ]], dtype=float32),
#  'The university was expanded with new buildings to accommodate more students and faculty.': array([[-0.00823845,  0.04086256,  0.07659241, ...,  0.12826413,
#           0.04072863,  0.04689581]], dtype=float32),
#  'The original Main Building built by Sorin just after he arrived was replaced by a larger "Main Building" in 1865, which housed the university\'s administration, classrooms, and dormitories.': array([[0.04579405, 0.04661052, 0.06078633, ..., 0.08675751, 0.02245101,
#          0.0538239 ]], dtype=float32),
#  'By 1879 it had grown to ten thousand volumes that were housed in the Main Building.': array([[ 0.07085521,  0.08658203,  0.02713388, ...,  0.26219308,
#          -0.00234202,  0.06560598]], dtype=float32),
#  'WSND-FM serves the student body and larger South Bend community at 88.9 FM, offering students a chance to become involved in bringing classical music, fine arts and educational programming, and alternative rock to the airwaves.': array([[ 0.10117302,  0.07965004,  0.07644757, ...,  0.03244616,
#          -0.03814263,  0.03887986]], dtype=float32),
#  'More recently, however, WVFI has been airing independently and is streamed on the Internet.': array([[ 0.07577503,  0.11628696,  0.08428098, ...,  0.04382302,
#          -0.03814263,  0.04327831]], dtype=float32),
#  'The Eddy Street Commons drew union protests when workers hired by the City of South Bend to construct the public parking garage picketed the private work site after a contractor hired non-union workers.': array([[ 0.08967587,  0.11959781,  0.11237646, ...,  0.09075065,
#          -0.015146  ,  0.07660557]], dtype=float32),
#  'Notre Dame teams are known as the Fighting Irish.': array([[ 0.07332864,  0.05096044,  0.02862613, ..., -0.03926745,
#          -0.03814263, -0.00343756]], dtype=float32),
#  'The Fighting Irish previously competed in the Horizon League from 1982-83 to 1985-86, and again from 1987-88 to 1994-95, and then in the Big East Conference through 2012–13.': array([[ 0.1199467 ,  0.20257775,  0.07092407, ..., -0.03926745,
#          -0.01392134,  0.06008341]], dtype=float32),
#  'The football team competes as an Football Bowl Subdivision (FBS) Independent since its inception in 1887.': array([[ 0.08627286,  0.06285945,  0.02065942, ...,  0.11443669,
#          -0.03814263,  0.03162423]], dtype=float32),
#  "Notre Dame's conference affiliations for all of its sports except football and fencing changed in July 2013 as a result of major conference realignment, and its fencing affiliation will change in July 2014.": array([[ 0.07351678,  0.17765753,  0.08667126, ...,  0.0076322 ,
#          -0.03013788,  0.02550622]], dtype=float32),
#  "In ice hockey, the Irish were forced to find a new conference home after the Big Ten Conference's decision to add the sport in 2013–14 led to a cascade of conference moves that culminated in the dissolution of the school's former hockey home, the Central Collegiate Hockey Association, after the 2012–13 season.": array([[ 0.07145029,  0.19185469,  0.09571585, ...,  0.05514428,
#          -0.00683705,  0.08368082]], dtype=float32),
#  'After Notre Dame joined the ACC, the conference announced it would add fencing as a sponsored sport beginning in the 2014–15 school year.': array([[ 0.05787097,  0.17629577,  0.06800966, ...,  0.05461748,
#          -0.01804189,  0.07863224]], dtype=float32),
#  'The official colors of Notre Dame are Navy Blue and Gold Rush which are worn in competition by its athletic teams.': array([[ 0.07086522,  0.26926988,  0.18470335, ..., -0.01228074,
#          -0.03814263,  0.03840431]], dtype=float32),
#  'The Notre Dame Leprechaun is the mascot of the athletic teams.': array([[ 0.06610078,  0.07367636,  0.07042745, ..., -0.03926745,
#          -0.03814263,  0.04758276]], dtype=float32),
#  'The leprechaun was featured on the cover of Time in November 1964 and gained national exposure.': array([[ 0.10662965,  0.116869  ,  0.09957469, ...,  0.06624085,
#          -0.03814263,  0.0309513 ]], dtype=float32),
#  'This contract, worth almost $100 million, is the most lucrative in the history of the NCAA.': array([[ 0.07635564,  0.16245368,  0.06097264, ...,  0.04875957,
#          -0.03814263, -0.01450074]], dtype=float32),
#  'The band, which began in 1846 and has a claim as the oldest university band in continuous existence in the United States, was honored by the National Music Council as a "Landmark of American Music" during the United States Bicentennial.': array([[ 0.12323993,  0.11970699,  0.04485137, ...,  0.07720132,
#          -0.02771348,  0.04578713]], dtype=float32),
#  'According to College Fight Songs: An Annotated Anthology published in 1998, the "Notre Dame Victory March" ranks as the greatest fight song of all time.': array([[ 0.09473661,  0.13851723,  0.07471273, ...,  0.03563369,
#          -0.02262098,  0.09919512]], dtype=float32),
#  'In the long history since then, 13 Fighting Irish teams have won consensus national championships (although the university only claims 11), along with another nine teams being named national champion by at least one source.': array([[ 0.05669712,  0.16741541,  0.03151221, ...,  0.12888193,
#          -0.03814263,  0.04043803]], dtype=float32),
#  'With the long history, Notre Dame has accumulated many rivals, and its annual game against USC for the Jeweled Shillelagh has been named by some as one of the most important in college football and is often called the greatest intersectional rivalry in college football in the country.': array([[ 0.12745796,  0.17169322,  0.09969671, ...,  0.02220905,
#          -0.03814263,  0.02622655]], dtype=float32),
#  'He played semiprofessional baseball and smoked, drank, and gambled when not playing sports.': array([[ 0.06718905, -0.01048787,  0.0969793 , ..., -0.03926745,
#          -0.03563374,  0.05707433]], dtype=float32),
#  'It was in 1928 that famed coach Knute Rockne used his final conversation with the dying Gipp to inspire the Notre Dame team to beat the Army team and "win one for the Gipper."': array([[ 0.07788698,  0.0689152 ,  0.09117761, ...,  0.04221105,
#          -0.03814263,  0.13111776]], dtype=float32),
#  'Today the team competes in Notre Dame Stadium, an 80,795-seat stadium on campus.': array([[ 0.09606066,  0.0719115 ,  0.0296932 , ...,  0.02993514,
#          -0.03485126,  0.00634876]], dtype=float32),
#  "Kelly's record in midway through his sixth season at Notre Dame is 52–21.": array([[ 0.07167911,  0.15886292,  0.04076714, ...,  0.05614468,
#          -0.03814263,  0.11898275]], dtype=float32),
#  'Kelly succeeded Charlie Weis, who was fired in November 2009 after five seasons.': array([[ 0.03311296,  0.16791202,  0.03277816, ...,  0.2380617 ,
#          -0.03814263,  0.14892098]], dtype=float32),
#  "The football team generates enough revenue to operate independently while $22.1 million is retained from the team's profits for academic use.": array([[ 0.05321841,  0.09756847,  0.02374058, ...,  0.03358617,
#          -0.00671157, -0.00747129]], dtype=float32),
#  'Football gameday traditions During home games, activities occur all around campus and different dorms decorate their halls with a traditional item (e.g.': array([[ 0.09720182,  0.03841862,  0.11078704, ...,  0.16209653,
#          -0.02204487, -0.01039527]], dtype=float32),
#  "Traditional activities begin at the stroke of midnight with the Drummers' Circle.": array([[ 0.05370306,  0.09493942,  0.08690531, ...,  0.01220716,
#          -0.03814263,  0.02328564]], dtype=float32),
#  'Later that day, the trumpet section will play the Notre Dame Victory March and the Notre Dame Alma Mater under the dome.': array([[ 0.02663203,  0.13211423,  0.02168612, ..., -0.01035009,
#          -0.03814263,  0.05707871]], dtype=float32),
#  "The men's basketball team has over 1,600 wins, one of only 12 schools who have reached that mark, and have appeared in 28 NCAA tournaments.": array([[ 0.08175894,  0.11270705,  0.08889388, ...,  0.06922089,
#          -0.03814263,  0.01493948]], dtype=float32),
#  'Although the team has never won the NCAA Tournament, they were named by the Helms Athletic Foundation as national champions twice.': array([[ 0.04073454,  0.04632476,  0.1459811 , ...,  0.0458103 ,
#          -0.03814263,  0.04681809]], dtype=float32),
#  "The team has beaten an additional eight number-one teams, and those nine wins rank second, to UCLA's 10, all-time in wins against the top team.": array([[ 0.09247659,  0.22311969,  0.07010315, ...,  0.18306586,
#          -0.03814263,  0.08325512]], dtype=float32),
#  'The team is coached by Mike Brey, who, as of the 2014–15 season, his fifteenth at Notre Dame, has achieved a 332-165 record.': array([[ 0.04748419,  0.08967443,  0.0356305 , ...,  0.07487399,
#          -0.03814263,  0.13479456]], dtype=float32),
#  "The 2010–11 team concluded its regular season ranked number seven in the country, with a record of 25–5, Brey's fifth straight 20-win season, and a second-place finish in the Big East.": array([[ 0.10332158,  0.21127252,  0.14742696, ...,  0.19621345,
#          -0.03814263,  0.05564887]], dtype=float32),
#  'Led by NBA draft picks Jerian Grant and Pat Connaughton, the Fighting Irish beat the eventual national champion Duke Blue Devils twice during the season.': array([[ 0.09386162,  0.2484544 ,  0.03842898, ...,  0.07197808,
#          -0.03814263,  0.14959495]], dtype=float32),
#  'The "Notre Dame Victory March" is the fight song for the University of Notre Dame.': array([[0.06989485, 0.16799752, 0.00440815, ..., 0.03218348, 0.00571858,
#          0.10250639]], dtype=float32),
#  'Michael J. Shea, a 1904 graduate, wrote the music, and his brother, John F. Shea, who earned degrees in 1906 and 1908, wrote the original lyrics.': array([[ 0.05265373,  0.14255959,  0.01742597, ...,  0.12885024,
#          -0.03814263,  0.17649478]], dtype=float32),
#  'The chorus is, "Cheer cheer for old Notre Dame, wake up the echos cheering her name.': array([[ 0.04447679,  0.05319074,  0.05000541, ...,  0.07006507,
#          -0.03814263,  0.03736525]], dtype=float32),
#  'What though the odds be great or small, old Notre Dame will win over all.': array([[ 0.01646987,  0.05496547,  0.06815523, ...,  0.02844045,
#          -0.03814263,  0.0349338 ]], dtype=float32),
#  'In the film Knute Rockne, All American, Knute Rockne (played by Pat O\'Brien) delivers the famous "Win one for the Gipper" speech, at which point the background music swells with the "Notre Dame Victory March".': array([[ 0.05292958,  0.12596405,  0.05802057, ...,  0.02338881,
#          -0.03814263,  0.19150381]], dtype=float32),
#  'This scene was parodied in the movie Airplane!': array([[ 0.12148303,  0.05024993,  0.10116173, ..., -0.03926745,
#          -0.03814263,  0.00221564]], dtype=float32),
#  'The song also was prominent in the movie Rudy, with Sean Astin as Daniel "Rudy" Ruettiger, who harbored dreams of playing football at the University of Notre Dame despite significant obstacles.': array([[ 0.07654767,  0.0932335 ,  0.06650048, ...,  0.01630368,
#          -0.01883748,  0.13158232]], dtype=float32),
#  'Alumni working in political fields include state governors, members of the United States Congress, and former United States Secretary of State Condoleezza Rice.': array([[ 0.12368359,  0.22860081,  0.04255904, ...,  0.03650272,
#          -0.03814263,  0.07533693]], dtype=float32),
#  "A number of university heads are alumni, including Notre Dame's current president, the Rev.": array([[ 0.04534311,  0.13915665,  0.03371725, ...,  0.08913468,
#          -0.02819898,  0.05482641]], dtype=float32),
# ...
#          -0.03814263, -0.00594376]], dtype=float32),
#  'With Jay Z what were her new themes?': array([[0.06226408, 0.06401382, 0.0205747 , ..., 0.14751059, 0.01026304,
#          0.15264721]], dtype=float32),
#  'What part of production does she do?': array([[ 0.0506316 ,  0.12677245, -0.03044511, ..., -0.03926745,
#          -0.03814263,  0.02756415]], dtype=float32),
#  'In addition to co-writing credits, Beyoncé also got what credits for most of her albums?': array([[ 0.03705068,  0.12989165,  0.06890804, ...,  0.12989925,
#          -0.03814263,  0.02361518]], dtype=float32),
#  'Pop Songwriter of the Year award in 2001 was awarded to whom?': array([[ 0.09975332,  0.12652172, -0.0038473 , ..., -0.00237193,
#          -0.03814263,  0.05401284]], dtype=float32),
#  'Beyonce has the same number of writing credits on number one singles as whom?': array([[ 0.10431454,  0.11603709,  0.09033388, ...,  0.09919354,
#          -0.03814263,  0.02462676]], dtype=float32),
#  'When did Beyonce become the first African American woman to win Pop songwriter of the year?': array([[ 0.07317838,  0.07348879,  0.20027775, ...,  0.027708  ,
#          -0.03814263,  0.06036526]], dtype=float32),
#  'Who listed her at number 17 in their list of  Top 20 hot 100 Songwriters?': array([[ 0.11949352,  0.12178606,  0.06910469, ...,  0.17851865,
#          -0.03814263,  0.03612648]], dtype=float32),
#  'What did Beyoncé win in 2001, making her the first black woman to do so?': array([[ 0.10615707,  0.10548305,  0.23303875, ...,  0.0376564 ,
#          -0.03078114,  0.02668727]], dtype=float32),
#  'Beyoncé was one of how many women on Billboard magazine\'s 2011 "Top 20 Hot 100 Songwriters" list.': array([[ 0.09163053,  0.12026795,  0.15302004, ...,  0.12138349,
#          -0.03814263,  0.05898706]], dtype=float32),
#  'To whom did Beyonce credit as her major influence on her music?': array([[ 0.06121195,  0.09051862,  0.07048257, ...,  0.08428808,
#          -0.03814263,  0.04025412]], dtype=float32),
#  'Beyonce gave a tribute award to who in 2006?': array([[ 0.07229753,  0.07175082,  0.05813828, ..., -0.02900819,
#          -0.02967115,  0.03413461]], dtype=float32),
#  'Who influenced Beyonce?': array([[ 0.09628354, -0.06247697,  0.12014326, ..., -0.03926745,
#          -0.03814263,  0.06474532]], dtype=float32),
#  "Who is Beyoncé's biggest musical influence?": array([[ 0.06501997,  0.05909472,  0.04319889, ...,  0.01238054,
#          -0.03814263,  0.01936137]], dtype=float32),
#  'Who does Beyoncé feel is an all-around entertainer?': array([[ 0.05628915,  0.04056204,  0.07204257, ..., -0.03926745,
#          -0.03814263, -0.02892259]], dtype=float32),
#  'What song caused Beyoncé to practice runs as a child?': array([[ 0.07517788,  0.0526666 ,  0.10968813, ..., -0.00764409,
#          -0.03814263,  0.02033785]], dtype=float32),
#  'Which singer did Beyonce honor by entertaining with her song "Deja Vu"?': array([[ 0.10391383, -0.00924659,  0.05904102, ...,  0.08510882,
#          -0.03814263,  0.05072376]], dtype=float32),
#  'What movie influenced Beyonce towards empowerment themes? ': array([[ 0.10202435,  0.0762684 ,  0.11713131, ...,  0.04750447,
#          -0.03814263,  0.04329162]], dtype=float32),
#  "Where did she perform wearing Baker's hula skirt?": array([[ 0.03178802,  0.12609547,  0.16601174, ..., -0.01802026,
#          -0.03814263,  0.14046419]], dtype=float32),
#  'What song did Beyoncé sing at a 2006 concert to honor Josephine Baker?': array([[ 0.07517788,  0.04727231, -0.00546012, ...,  0.00628063,
#          -0.03814263,  0.14541028]], dtype=float32),
#  'Which month and year did Beyonce credit Madonna for inspiring her to take control of her career?': array([[ 0.00569935,  0.08819246,  0.06123793, ...,  0.08675691,
#          -0.03814263,  0.03687521]], dtype=float32),
#  'Who personally influences Beyonce?': array([[ 0.09085044, -0.05498715,  0.11341985, ..., -0.03926745,
#          -0.03814263, -0.00316154]], dtype=float32),
#  'How does she describe Jean- Michel Basquiat?': array([[ 0.02751765, -0.07579605,  0.14010762, ..., -0.01452444,
#          -0.03814263, -0.02892259]], dtype=float32),
#  'How does she describe Jay Z?': array([[ 0.02751765, -0.0260308 ,  0.04533348, ..., -0.03822318,
#          -0.03814263,  0.1372439 ]], dtype=float32),
#  'Who does Beyoncé describe as the definition of inspiration?': array([[ 0.03797784,  0.1134914 ,  0.08434045, ..., -0.00610493,
#          -0.03814263, -0.00751773]], dtype=float32),
#  'Who inspired Beyoncé to take control of her career?': array([[ 0.08183423,  0.10779192,  0.07714134, ...,  0.08675691,
#          -0.03814263, -0.02892259]], dtype=float32),
#  'Beyonce had singers in the background known by the name as?': array([[ 0.13671303,  0.05974076,  0.05813828, ...,  0.02864468,
#          -0.03814263,  0.05271673]], dtype=float32),
#  'The Mamas first appearance was when?': array([[ 0.00056812,  0.03114215,  0.16563968, ..., -0.016215  ,
#          -0.03814263,  0.04674087]], dtype=float32),
#  "What song name does the band Suga Mama  and a song on the B'Day album share?": array([[ 0.09541975,  0.03266839,  0.05767645, ...,  0.06808238,
#          -0.03814263,  0.13835749]], dtype=float32),
#  'What band supports Beyonce in her tours?': array([[ 0.1455704 ,  0.04687552,  0.03884516, ...,  0.13507724,
#          -0.03814263,  0.02050343]], dtype=float32),
#  'Suga Mama is also a song on which Beyoncé album?': array([[ 0.085641  ,  0.04627502,  0.12469897, ...,  0.06808238,
#          -0.03814263,  0.13685064]], dtype=float32),
#  'When did The Mamas make their debut?': array([[ 0.01351372,  0.01482796,  0.01570411, ...,  0.11557508,
#          -0.03814263,  0.04615084]], dtype=float32),
#  'Which former president of Def Jam called Beyonce the greatest entertainer alive?': array([[ 0.1181194 ,  0.13111092,  0.05681464, ..., -0.03926745,
#          -0.03814263,  0.07237966]], dtype=float32),
#  'Who chose her as number one on his list of Best singers/ Dancers?': array([[ 0.07510092,  0.09404231,  0.08409181, ...,  0.11381787,
#          -0.03275787,  0.04449367]], dtype=float32),
#  'How does Alice Jones describe her?': array([[ 0.05593088,  0.04376254,  0.01944349, ...,  0.05456857,
#          -0.03814263,  0.12986201]], dtype=float32),
#  'Who has said that Beyoncé is the best entertainer alive?': array([[ 0.10034025,  0.04778893,  0.08948306, ..., -0.03926745,
#          -0.03814263,  0.05518449]], dtype=float32),
#  'Her alter ego was born when according to Beyonce?': array([[ 0.09211451,  0.08491993,  0.10235504, ..., -0.02525706,
#          -0.03518558,  0.12188707]], dtype=float32),
#  'Beyonce brought back Sasha Fierce during which event?': array([[ 0.06551486, -0.01984277,  0.05813828, ..., -0.00752772,
#          -0.03814263,  0.03662389]], dtype=float32),
#  'Later what did she say about Sasha?': array([[ 0.0204008 , -0.005215  , -0.01088814, ..., -0.03926745,
#          -0.03814263,  0.07108174]], dtype=float32),
#  'When did Beyoncé introduce Sasha Fierce?': array([[ 0.05311247, -0.08939897,  0.01144168, ..., -0.03926745,
#          -0.03814263,  0.02956077]], dtype=float32),
#  'Who did Beyoncé tell in February 2010 that Sasha Fierce was no longer needed?': array([[ 0.1150241 ,  0.13527769,  0.04189608, ..., -0.03489958,
#          -0.03814263,  0.01008611]], dtype=float32),
#  'Which music journalist described Beyonce as a "crossover sex symbol?"': array([[ 0.09395645,  0.06169722,  0.14443181, ..., -0.02775207,
#          -0.03814263,  0.00137859]], dtype=float32),
#  'Bootylicious was a song from which act that Beyonce performed with?': array([[ 0.03650147,  0.00323941,  0.0711133 , ...,  0.09712978,
#          -0.03814263,  0.03411594]], dtype=float32),
#  'What word is often used to describe Beyonce/': array([[ 0.06860167, -0.00482293,  0.11066713, ..., -0.01237855,
#           0.00688619,  0.02595427]], dtype=float32),
#  'What journalist wrote that Beyoncé was a "sex symbol"?': array([[ 0.07452136,  0.01013407,  0.13523746, ..., -0.02444345,
#          -0.03814263,  0.01473023]], dtype=float32),
#  "In what year was the slang term from a title of a Destiny's Child song that is also used to describe Beyoncé put in the dictionary?": array([[ 0.07503308,  0.11890333,  0.12354371, ..., -0.00115392,
#           0.00594574,  0.00686845]], dtype=float32),
#  'in September 2010, what career area did Beyonce start exploring?': array([[ 0.10361352,  0.10009847,  0.04642706, ...,  0.0032906 ,
#          -0.03814263,  0.03893991]], dtype=float32),
#  '"World\'s Most Beautiful woman" was declared to Beyonce by which national magazine?': array([[ 0.08897179,  0.09053516,  0.16058774, ..., -0.01169998,
#          -0.02872901,  0.0180256 ]], dtype=float32),
#  'What TV network listed Beyonce as number 1 on its 100 Sexiest Artists list?': array([[ 0.18522206,  0.15741041,  0.10562635, ...,  0.10585244,
#          -0.03097082,  0.05921575]], dtype=float32),
#  'Who called her Hottest Female Singer of all Time?': array([[ 0.16332762,  0.10663407,  0.09002687, ..., -0.01807597,
#          -0.03814263,  0.11794616]], dtype=float32),
#  'VH1 listed her at what number on their 100 Sexiest Artists list?': array([[ 0.17974153,  0.08127111,  0.12345053, ...,  0.1407169 ,
#          -0.03097082,  0.05104955]], dtype=float32),
#  'What magazine said Beyoncé was the "World\'s Most Beautiful Woman"?': array([[ 0.08865645,  0.07553345,  0.09350647, ..., -0.03926745,
#          -0.03814263,  0.06576947]], dtype=float32),
#  'What museum has made several models of Beyoncé in wax?': array([[0.08243314, 0.11239237, 0.11701132, ..., 0.09078337, 0.01841743,
#          0.00744703]], dtype=float32),
#  'Which African-American woman before Beyonce had posed for SI Swimsuit issue?': array([[ 0.04658533,  0.01465713,  0.20305951, ..., -0.02871615,
#          -0.0281709 ,  0.01995722]], dtype=float32),
#  'When was she on the Sports Illustrated cover?': array([[ 0.06241498,  0.07098354,  0.05076579, ..., -0.00435277,
#          -0.03814263,  0.03539547]], dtype=float32),
#  'Beyoncé was the second African American woman featured as a swimsuit cover on the magazine, who was first?': array([[ 0.13131036,  0.12823467,  0.20951828, ...,  0.02701899,
#          -0.03814263,  0.0166456 ]], dtype=float32),
#  'Beyonce has a fan base that is referred to as what?': array([[ 0.10431454,  0.05429499,  0.05813828, ..., -0.03926745,
#          -0.03814263,  0.00602587]], dtype=float32),
#  'Which social media company proclaimed Beyonce fans are know as the Bey Hive?': array([[ 0.14121069,  0.12129575,  0.0666334 , ..., -0.00224141,
#          -0.03814263,  0.02004582]], dtype=float32),
#  'What did the fans used to be called?': array([[ 0.04142356,  0.06607178,  0.04356646, ..., -0.03386833,
#           0.00884545,  0.03237582]], dtype=float32),
#  'What was the former word given to Beyoncé fans?': array([[ 0.03269096,  0.0501149 ,  0.05741816, ..., -0.03926745,
#          -0.03814263,  0.07288688]], dtype=float32),
#  'Beyonce has a clothing line known as what?': array([[ 0.10431454,  0.03347761,  0.19439848, ..., -0.03926745,
#          -0.03814263,  0.01122214]], dtype=float32),
#  'Beyonce was seen wearing what on the french magazine that caused controversy?': array([[ 0.08594639,  0.07303341,  0.21531901, ..., -0.03907005,
#          -0.03814263,  0.03516437]], dtype=float32),
#  'What did PETA criticize Beyonce for in 2006?': array([[ 0.08708236,  0.08582848,  0.04818742, ..., -0.01669075,
#          -0.0369232 ,  0.02423226]], dtype=float32),
#  "How was she dressed on the cover of L'Officiel?": array([[ 0.07393314,  0.10181911,  0.09335479, ...,  0.01669909,
#          -0.03814263,  0.00178054]], dtype=float32),
#  'What clothing line of Beyoncé drew PETA criticism?': array([[ 0.1055695 ,  0.1398562 ,  0.15147607, ..., -0.03790907,
#          -0.03814263,  0.01773596]], dtype=float32),
#  'Which racial community gave criticism to Beyonce?': array([[ 0.10532046,  0.02419765,  0.09145477, ..., -0.03926745,
#          -0.02413701,  0.05137615]], dtype=float32),
#  "Which company was accused of coloring Beyonce's hair?": array([[ 0.05810819,  0.14538245,  0.26039314, ..., -0.00589507,
#          -0.03814263,  0.03917689]], dtype=float32),
#  "How did L'Oreal respond to accusations of changing pictures?": array([[ 0.04152172,  0.11268576,  0.00641357, ...,  0.0189393 ,
#          -0.02736945,  0.02283693]], dtype=float32),
#  'In 2007, which music professor said he believes this criticism does involve race as well?': array([[ 5.3863615e-02,  8.2603917e-02,  3.4569781e-05, ...,
#          -3.9267451e-02, -3.8142629e-02,  1.7909661e-01]], dtype=float32),
#  "What advertisement was Beyoncé's skin supposedly lightened in?": array([[ 0.10040803,  0.07089844,  0.15940887, ...,  0.02986363,
#          -0.01925309,  0.03983667]], dtype=float32),
#  'Artist of the Decade was bestowed upon Beyonce from which magazine?': array([[ 0.06224627,  0.11115515,  0.09976   , ..., -0.02971588,
#          -0.03814263,  0.05249599]], dtype=float32),
#  'Beyonce than appeared again on the Time 100 list in what year?': array([[ 0.08684945,  0.10040501,  0.07456306, ...,  0.08709084,
#          -0.02693206,  0.06870115]], dtype=float32),
#  'When did Beyonce first make the Time 100 List?': array([[ 0.03547542,  0.04728173,  0.0500206 , ...,  0.06452223,
#          -0.00591927,  0.06791831]], dtype=float32),
#  'Who said that she is the reigning national voice?': array([[ 0.0499603 ,  0.09081352,  0.01098747, ..., -0.03926745,
#          -0.02956404,  0.0605659 ]], dtype=float32),
#  'Which publication named Beyoncé the Artist of the Decade?': array([[ 0.07052495,  0.10066746,  0.08260529, ..., -0.02843898,
#          -0.03814263,  0.05759179]], dtype=float32),
#  'Who said Beyoncé is the heir-apparent diva of the United States?': array([[ 0.12150793,  0.10005485,  0.14196762, ..., -0.03926745,
#          -0.03814263,  0.05693819]], dtype=float32),
#  'Which rock band cited Beyonce on their third album?': array([[ 0.1284596 ,  0.1359459 ,  0.11514644, ...,  0.12673727,
#          -0.03814263,  0.03822269]], dtype=float32),
#  'Nicky Minaj became a spokesperson for which brand of soda after seeing Beyonce involved with it?': array([[ 0.08747584,  0.11935233,  0.10663043, ...,  0.00555476,
#          -0.03814263,  0.08556619]], dtype=float32),
#  'Which band listed Beyonce as an inspiration on their latest album?': array([[ 0.15987156,  0.08253955,  0.0917868 , ...,  0.15040831,
#          -0.03814263,  0.01375895]], dtype=float32),
#  'For what film was Paltrow studying Beyonce ?': array([[ 0.04307914, -0.00790728,  0.1399919 , ..., -0.03926745,
#          -0.03814263,  0.02474264]], dtype=float32),
#  "What was the name of the White Rabbits' album?": array([[ 0.06317843,  0.12825102,  0.02505786, ...,  0.06808238,
#          -0.03814263,  0.08179064]], dtype=float32),
#  'What was the name of the film that Gwyneth Paltrow starred in as a musician?': array([[ 0.10567611,  0.08851346,  0.17693055, ..., -0.03005757,
#          -0.03814263,  0.05401004]], dtype=float32),
#  'VH1 declared what song the "Greatest song of the 2000s?"': array([[ 0.09628822,  0.05362076,  0.04500611, ...,  0.02788398,
#          -0.03814263,  0.04183401]], dtype=float32),
#  'How many did Crazy in Love sell to become one of the greatest selling singles in history?': array([[ 0.10059562,  0.1056257 ,  0.03135952, ..., -0.00467693,
#          -0.03814263,  0.04317215]], dtype=float32),
#  'A place for Beyonce in the Rock and Roll Hall of fame was awarded when?': array([[ 0.08039011,  0.09714246,  0.04828557, ..., -0.01805689,
#          -0.03814263,  0.07205706]], dtype=float32),
#  'How many Grammy awards did Crazy in Love get?': array([[ 0.08718482,  0.07159284,  0.04370072, ...,  0.09713751,
#          -0.03814263,  0.0520718 ]], dtype=float32),
#  'Who released the single Girls Love Beyonce?': array([[ 0.05670759,  0.09010763,  0.01582006, ..., -0.03558218,
#          -0.03814263,  0.04268311]], dtype=float32),
#  'Who sang "Girls Love Beyoncé" in 2013?': array([[ 0.11354569,  0.0966864 ,  0.05201412, ..., -0.03468847,
#          -0.03814263,  0.03470871]], dtype=float32),
#  ...}

# %%
d2
# Out:
# {"Atop the Main Building's gold dome is a golden statue of the Virgin Mary.": array([[ 0.07475325,  0.11794458,  0.06240867, ...,  0.01915886,
#          -0.02436746,  0.10806957]], dtype=float32),
#  'Next to the Main Building is the Basilica of the Sacred Heart.': array([[ 0.08010551,  0.11775322,  0.02186233, ...,  0.01656766,
#          -0.01024127,  0.04706628]], dtype=float32),
#  'It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858.': array([[ 0.10776819,  0.0805801 ,  0.10461736, ...,  0.01522135,
#          -0.03814263,  0.14945611]], dtype=float32),
#  "As at most other universities, Notre Dame's students run a number of news media outlets.": array([[0.09720325, 0.09345725, 0.05466026, ..., 0.08443642, 0.00817084,
#          0.02197512]], dtype=float32),
#  'Begun as a one-page journal in September 1876, the Scholastic magazine is issued twice monthly and claims to be the oldest continuous collegiate publication in the United States.': array([[ 0.11371739,  0.06475341,  0.06018969, ...,  0.10787066,
#          -0.01113451,  0.0456443 ]], dtype=float32),
#  'The Dome yearbook is published annually.': array([[ 0.05401575,  0.08173893,  0.06005874, ...,  0.04812558,
#           0.00550616, -0.02892259]], dtype=float32),
#  'Unlike Scholastic and The Dome, The Observer is an independent publication and does not have a faculty advisor or any editorial oversight from the University.': array([[ 0.02566787,  0.1244874 ,  0.04215277, ..., -0.01121548,
#           0.03177883,  0.09949251]], dtype=float32),
#  'Likewise, in 2003, when other students believed that the paper showed a liberal bias, the conservative paper Irish Rover went into production.': array([[0.10532634, 0.10208918, 0.05500188, ..., 0.07356755, 0.00575096,
#          0.09861569]], dtype=float32),
#  'Finally, in Spring 2008 an undergraduate journal for political science research, Beyond Politics, made its debut.': array([[0.10228813, 0.17520438, 0.02581729, ..., 0.05633542, 0.07295044,
#          0.04592503]], dtype=float32),
#  'Its main seminary, Moreau Seminary, is located on the campus across St. Joseph lake from the Main Building.': array([[ 0.11057335,  0.06101721,  0.07647947, ...,  0.08353081,
#          -0.00234202,  0.19278482]], dtype=float32),
#  'Retired priests and brothers reside in Fatima House (a former retreat center), Holy Cross House, as well as Columba Hall near the Grotto.': array([[ 0.16535495,  0.04214511,  0.07595828, ...,  0.01540594,
#          -0.03370908,  0.13150463]], dtype=float32),
#  'While not Catholic, Buechner has praised writers from Notre Dame and Moreau Seminary created a Buechner Prize for Preaching.': array([[0.02664018, 0.08281331, 0.02671024, ..., 0.02672899, 0.02204712,
#          0.13037314]], dtype=float32),
#  'Today the college, housed in the Fitzpatrick, Cushing, and Stinson-Remick Halls of Engineering, includes five departments of study – aerospace and mechanical engineering, chemical and biomolecular engineering, civil engineering and geological sciences, computer science and engineering, and electrical engineering – with eight B.S.': array([[0.08357788, 0.2089905 , 0.03492033, ..., 0.25156334, 0.02195479,
#          0.06164518]], dtype=float32),
#  'Additionally, the college offers five-year dual degree programs with the Colleges of Arts and Letters and of Business awarding additional B.A.': array([[0.04605094, 0.11072335, 0.03675867, ..., 0.10897492, 0.01040785,
#          0.04920864]], dtype=float32),
#  "All of Notre Dame's undergraduate students are a part of one of the five undergraduate colleges at the school or are in the First Year of Studies program.": array([[0.04991942, 0.17617176, 0.02490164, ..., 0.26093692, 0.06571009,
#          0.07436202]], dtype=float32),
#  'Each student is given an academic advisor from the program who helps them to choose classes that give them exposure to any major in which they are interested.': array([[0.06798847, 0.08381264, 0.05650055, ..., 0.0066453 , 0.00525633,
#          0.01817128]], dtype=float32),
#  'This program has been recognized previously, by U.S. News & World Report, as outstanding.': array([[0.05539125, 0.14508384, 0.07582746, ..., 0.01847365, 0.00862252,
#          0.04388386]], dtype=float32),
#  'The program expanded to include Master of Laws (LL.M.)': array([[-0.00386952,  0.08890707,  0.04676745, ...,  0.07625403,
#          -0.00666403,  0.03454939]], dtype=float32),
#  'This changed in 1924 with formal requirements developed for graduate degrees, including offering Doctorate (PhD) degrees.': array([[0.11137418, 0.07385464, 0.07146702, ..., 0.13178422, 0.01856664,
#          0.1078368 ]], dtype=float32),
#  'Most of the departments from the College of Arts and Letters offer PhD programs, while a professional Master of Divinity (M.Div.)': array([[0.0796931 , 0.13099755, 0.04544546, ..., 0.03162469, 0.0126572 ,
#          0.07585437]], dtype=float32),
#  'All of the departments in the College of Science offer PhD programs, except for the Department of Pre-Professional Studies.': array([[0.08973558, 0.14068209, 0.02882394, ..., 0.02568279, 0.0644524 ,
#          0.07213583]], dtype=float32),
#  'The College of Business offers multiple professional programs including MBA and Master of Science in Accountancy programs.': array([[0.04702467, 0.12294327, 0.02849153, ..., 0.10099187, 0.06988789,
#          0.06625377]], dtype=float32),
#  'Additionally, the Alliance for Catholic Education program offers a Master of Education program where students study at the university during the summer and teach in Catholic elementary schools, middle schools, and high schools across the Southern United States for two school years.': array([[0.13279222, 0.15727934, 0.05935455, ..., 0.20690939, 0.02919947,
#          0.05995496]], dtype=float32),
#  "It offers PhD, Master's, and undergraduate degrees in peace studies.": array([[0.08632088, 0.1238444 , 0.0300626 , ..., 0.11045288, 0.04434446,
#          0.11648887]], dtype=float32),
#  'The institute was inspired by the vision of the Rev.': array([[ 0.02319467,  0.08547275,  0.07028665, ..., -0.01150543,
#           0.00596578,  0.04989189]], dtype=float32),
#  'The institute has contributed to international policy discussions about peace building practices.': array([[0.06034546, 0.02940578, 0.04847679, ..., 0.07820953, 0.01423112,
#          0.00260395]], dtype=float32),
#  'The main building is the 14-story Theodore M. Hesburgh Library, completed in 1963, which is the third building to house the main collection of books.': array([[0.07290702, 0.12258399, 0.09523359, ..., 0.09780817, 0.03700107,
#          0.12277223]], dtype=float32),
#  'This mural is popularly known as "Touchdown Jesus" because of its proximity to Notre Dame Stadium and Jesus\' arms appearing to make the signal for a touchdown.': array([[ 0.08877291,  0.06938668,  0.13218386, ...,  0.00134168,
#          -0.02374697,  0.08423566]], dtype=float32),
#  'The academic profile of the enrolled class continues to rate among the top 10 to 15 in the nation for national research universities.': array([[0.0812694 , 0.10498182, 0.12887417, ..., 0.08791424, 0.05245126,
#          0.09775289]], dtype=float32),
#  '1,400 of the 3,577 (39.1%) were admitted under the early action plan.': array([[ 0.01952762,  0.12629421,  0.04650823, ...,  0.07424419,
#          -0.03814263,  0.05669221]], dtype=float32),
#  'While all entering students begin in the College of the First Year of Studies, 25% have indicated they plan to study in the liberal arts or social sciences, 24% in engineering, 24% in business, 24% in science, and 3% in architecture.': array([[0.07766196, 0.14719719, 0.04130385, ..., 0.14042613, 0.02796853,
#          0.07661854]], dtype=float32),
#  'In 2014, USA Today ranked Notre Dame 10th overall for American universities based on data from College Factual.': array([[0.15250449, 0.21034954, 0.03360581, ..., 0.06898621, 0.06198179,
#          0.04119638]], dtype=float32),
#  'U.S. News & World Report also lists Notre Dame Law School as 22nd overall.': array([[0.13020115, 0.12328333, 0.03833554, ..., 0.02363728, 0.03027548,
#          0.07376049]], dtype=float32),
#  'It ranks the MBA program as 20th overall.': array([[ 0.10658257,  0.11642093,  0.048433  , ...,  0.01882075,
#           0.03722707, -0.00483528]], dtype=float32),
#  'Additionally, the study abroad program ranks sixth in highest participation percentage in the nation, with 57.6% of students choosing to study abroad in 17 countries.': array([[0.12909772, 0.20049423, 0.06081488, ..., 0.13266177, 0.02502567,
#          0.04398495]], dtype=float32),
#  'The median starting salary of $55,300 ranked 58th in the same peer group.': array([[ 0.08268112,  0.22229116,  0.07839518, ...,  0.09968933,
#          -0.02019984, -0.02892259]], dtype=float32),
#  'was Director of the Science Museum and the Library and Professor of Chemistry and Physics until 1874.': array([[0.00346082, 0.15533713, 0.00479969, ..., 0.05197828, 0.06039625,
#          0.12655877]], dtype=float32),
#  "One of Carrier's students was Father John Augustine Zahm (1851–1921) who was made Professor and Co-Director of the Science Department at age 23 and by 1900 was a nationally prominent scientist and naturalist.": array([[ 0.08040841,  0.11984704,  0.02540394, ...,  0.07974376,
#          -0.01408419,  0.1532366 ]], dtype=float32),
#  'His book Evolution and Dogma (1896) defended certain aspects of evolutionary theory as true, and argued, moreover, that even the great Church teachers Thomas Aquinas and Augustine taught something like it.': array([[ 0.02928695,  0.09801161,  0.01788417, ...,  0.01253256,
#          -0.03814263,  0.13025661]], dtype=float32),
#  'In 1913, Zahm and former President Theodore Roosevelt embarked on a major expedition through the Amazon.': array([[ 0.05933293,  0.0784094 ,  0.04986344, ...,  0.02391768,
#          -0.03814263,  0.10508335]], dtype=float32),
#  'Around 1899, Professor Jerome Green became the first American to send a wireless message.': array([[ 0.03759136,  0.2302522 ,  0.04406688, ..., -0.03791297,
#           0.04393638,  0.17691143]], dtype=float32),
#  'Study of nuclear physics at the university began with the building of a nuclear accelerator in 1936, and continues now partly through a partnership in the Joint Institute for Nuclear Astrophysics.': array([[0.05906717, 0.16384493, 0.04000631, ..., 0.06037233, 0.04578524,
#          0.09761987]], dtype=float32),
#  'This area of research originated in a question posed by Pasteur as to whether animal life was possible without bacteria.': array([[0.11465366, 0.11499084, 0.09670055, ..., 0.04834221, 0.01463899,
#          0.03038035]], dtype=float32),
#  'Lobund was the first research organization to answer definitively, that such life is possible and that it can be prolonged through generations.': array([[0.03005806, 0.08640376, 0.10478375, ..., 0.01302195, 0.05510143,
#          0.01656807]], dtype=float32),
#  'This objective was reached and for years Lobund was a unique center for the study and production of germ free animals and for their use in biological and medical investigations.': array([[0.05539125, 0.09482188, 0.03247559, ..., 0.10848658, 0.0207355 ,
#          0.08154181]], dtype=float32),
#  "In the beginning it was under the Department of Biology and a program leading to the master's degree accompanied the research program.": array([[0.04404324, 0.20985752, 0.03229897, ..., 0.08158819, 0.04894062,
#          0.11110418]], dtype=float32),
#  'In 1958 it was brought back into the Department of Biology as integral part of that department, but with its own program leading to the degree of PhD in Gnotobiotics.': array([[0.05162722, 0.20557413, 0.04034692, ..., 0.10517055, 0.01052318,
#          0.09287757]], dtype=float32),
#  'It quickly emerged as part of an international Catholic intellectual revival, offering an alternative vision to positivist philosophy.': array([[ 0.11673211,  0.13902473,  0.17771159, ...,  0.01454948,
#          -0.03814263,  0.03924542]], dtype=float32),
#  "Intellectual leaders included Gurian, Jacques Maritain, Frank O'Malley, Leo Richard Ward, F. A. Hermens, and John U. Nef.": array([[ 0.06116005,  0.09223651, -0.00506638, ..., -0.02537771,
#          -0.03814263,  0.1487805 ]], dtype=float32),
#  'As of 2012[update] research continued in many fields.': array([[0.03652489, 0.14855036, 0.05446412, ..., 0.0701194 , 0.01430065,
#          0.06022778]], dtype=float32),
#  'The university has many multi-disciplinary institutes devoted to research in varying fields, including the Medieval Institute, the Kellogg Institute for International Studies, the Kroc Institute for International Peace studies, and the Center for Social Concerns.': array([[0.07628564, 0.17651547, 0.05159802, ..., 0.09109764, 0.05796776,
#          0.11226782]], dtype=float32),
#  'As of 2013, the university is home to the Notre Dame Global Adaptation Index which ranks countries annually based on how vulnerable they are to climate change and how prepared they are to adapt.': array([[0.15113291, 0.18062408, 0.10039786, ..., 0.06364247, 0.0487792 ,
#          0.02078816]], dtype=float32),
#  'students.': array([[-0.01988107,  0.0018695 ,  0.00818553, ..., -0.00778225,
#          -0.03814263, -0.02892259]], dtype=float32),
#  "As of March 2007[update] The Princeton Review ranked the school as the fifth highest 'dream school' for parents to send their children.": array([[0.03075957, 0.19617377, 0.05903006, ..., 0.16967191, 0.00669653,
#          0.04465436]], dtype=float32),
#  'The school has been previously criticized for its lack of diversity, and The Princeton Review ranks the university highly among schools at which "Alternative Lifestyles [are] Not an Alternative."': array([[ 0.03774641,  0.10780253,  0.0783337 , ...,  0.03715659,
#          -0.02999719,  0.02442738]], dtype=float32),
#  'With 6,000 participants, the university\'s intramural sports program was named in 2004 by Sports Illustrated as the best program in the country, while in 2007 The Princeton Review named it as the top school where "Everyone Plays Intramural Sports."': array([[ 0.08290663,  0.14154841,  0.1025629 , ...,  0.05073835,
#          -0.00859714,  0.02620561]], dtype=float32),
#  'About 80% of undergraduates and 20% of graduate students live on campus.': array([[ 0.08224858,  0.15511142,  0.03336356, ...,  0.16808598,
#          -0.02263778,  0.02574326]], dtype=float32),
#  'Because of the religious affiliation of the university, all residence halls are single-sex, with 15 male dorms and 14 female dorms.': array([[ 0.02701605,  0.11702128,  0.02332135, ...,  0.08638503,
#          -0.03814263, -0.01406626]], dtype=float32),
#  'Many residence halls have at least one nun and/or priest as a resident.': array([[ 0.02564337, -0.00219719,  0.04608788, ...,  0.03163227,
#          -0.03814263,  0.00786741]], dtype=float32),
#  'Some intramural sports are based on residence hall teams, where the university offers the only non-military academy program of full-contact intramural American football.': array([[ 0.09500013,  0.09213197,  0.04906011, ...,  0.07843472,
#          -0.00971006, -0.01295836]], dtype=float32),
#  'The university is affiliated with the Congregation of Holy Cross (Latin: Congregatio a Sancta Cruce, abbreviated postnominals: "CSC").': array([[ 0.0433717 ,  0.07815041,  0.10635944, ...,  0.04076243,
#          -0.0036218 ,  0.01547514]], dtype=float32),
#  'Collectively, Catholic Mass is celebrated over 100 times per week on campus, and a large campus ministry program provides for the faith needs of the community.': array([[0.05421379, 0.1947617 , 0.0264846 , ..., 0.10941827, 0.02999648,
#          0.02897265]], dtype=float32),
#  'Additionally, every classroom displays a crucifix.': array([[ 0.04433528, -0.01515355,  0.046816  , ...,  0.07646967,
#          -0.0294295 ,  0.00370678]], dtype=float32),
#  'The Notre Dame KofC are known for being the first collegiate council of KofC, operating a charitable concession stand during every home football game and owning their own building on campus which can be used as a cigar lounge.': array([[0.06468683, 0.06873858, 0.0962758 , ..., 0.19696105, 0.01112977,
#          0.00094805]], dtype=float32),
#  'This Main Building, and the library collection, was entirely destroyed by a fire in April 1879, and the school closed immediately and students were sent home.': array([[0.09515969, 0.09667318, 0.07549826, ..., 0.02278368, 0.00568171,
#          0.0307206 ]], dtype=float32),
#  'Sorin and the president at the time, the Rev.': array([[ 0.00701071,  0.05865769,  0.00627084, ..., -0.01926443,
#          -0.03814263,  0.04989189]], dtype=float32),
#  'Construction was started on the 17th of May and by the incredible zeal of administrator and workers the building was completed before the fall semester of 1879.': array([[0.01914052, 0.10733381, 0.06635998, ..., 0.07190806, 0.00913186,
#          0.02692104]], dtype=float32),
#  'Around the time of the fire, a music hall was opened.': array([[ 0.05045357,  0.0922111 ,  0.03750201, ...,  0.02322967,
#          -0.03005484,  0.00905087]], dtype=float32),
#  'By 1880, a science program was established at the university, and a Science Hall (today LaFortune Student Center) was built in 1883.': array([[0.03708706, 0.10251744, 0.00378605, ..., 0.05085646, 0.00316238,
#          0.09551839]], dtype=float32),
#  "In 1919 Father James Burns became president of Notre Dame, and in three years he produced an academic revolution that brought the school up to national standards by adopting the elective system and moving away from the university's traditional scholastic and classical emphasis.": array([[0.04090814, 0.15895252, 0.06537418, ..., 0.20563634, 0.00128498,
#          0.16452914]], dtype=float32),
#  'Their graduates were shut out of Harvard Law School for that reason.': array([[0.03291047, 0.11969398, 0.00305759, ..., 0.0421735 , 0.03778399,
#          0.06492266]], dtype=float32),
#  'By 1921, with the addition of the College of Commerce, Notre Dame had grown from a small college to a university with five colleges and a professional law school.': array([[0.03402645, 0.14965098, 0.02253845, ..., 0.21442461, 0.02110403,
#          0.05835322]], dtype=float32),
#  'One of the main driving forces in the growth of the University was its football team, the Notre Dame Fighting Irish.': array([[ 0.09887696,  0.1292865 ,  0.05410837, ...,  0.05242919,
#          -0.03814263,  0.12329702]], dtype=float32),
#  'Under Rockne, the Irish would post a record of 105 wins, 12 losses, and five ties.': array([[ 0.03313781,  0.1701788 ,  0.04997446, ...,  0.18795732,
#          -0.03814263,  0.08965186]], dtype=float32),
#  'Knute Rockne has the highest winning percentage (.881) in NCAA Division I/FBS football history.': array([[ 0.06548414,  0.12550424,  0.06384934, ...,  0.10830057,
#          -0.03814263,  0.09547799]], dtype=float32),
#  'The last game Rockne coached was on December 14, 1930 when he led a group of Notre Dame all-stars against the New York Giants in New York City.': array([[ 0.07785925,  0.12257671,  0.03636733, ...,  0.01035125,
#          -0.03814263,  0.14536873]], dtype=float32),
#  'The success of Note Dame reflected rising status of Irish Americans and Catholics in the 1920s.': array([[ 0.06645156,  0.1184647 ,  0.08986322, ...,  0.00093154,
#          -0.03814263,  0.02414911]], dtype=float32),
#  'Yet this role as high-profile flagship institution of Catholicism made it an easy target of anti-Catholicism.': array([[ 0.1140916 ,  0.15415286,  0.1619362 , ..., -0.02852794,
#          -0.03814263,  0.05397058]], dtype=float32),
#  "Nativism and anti-Catholicism, especially when directed towards immigrants, were cornerstones of the KKK's rhetoric, and Notre Dame was seen as a symbol of the threat posed by the Catholic Church.": array([[ 0.10071021,  0.11744715,  0.12511028, ...,  0.03824164,
#          -0.03814263,  0.06180733]], dtype=float32),
#  'Clashes with the student body started on March 17, when students, aware of the anti-Catholic animosity, blocked the Klansmen from descending from their trains in the South Bend station and ripped the KKK clothes and regalia.': array([[ 0.0928091 ,  0.15834245,  0.21101677, ...,  0.12571053,
#          -0.01050172,  0.04058797]], dtype=float32),
#  'Matthew Walsh prevented any further clashes.': array([[ 0.01226653,  0.04264211,  0.1065757 , ..., -0.01627446,
#          -0.03814263,  0.15906243]], dtype=float32),
#  'A few days later the Klavern broke up, but the hostility shown by the students was an omen and a contribution to the downfall of the KKK in Indiana.': array([[ 0.10585672,  0.09127115,  0.13176888, ...,  0.10079764,
#          -0.03814263,  0.03494614]], dtype=float32),
#  'During his tenure at Notre Dame, he brought numerous refugee intellectuals to campus; he selected Frank H. Spearman, Jeremiah D. M. Ford, Irvin Abell, and Josephine Brownson for the Laetare Medal, instituted in 1883.': array([[0.05671094, 0.09611284, 0.12181317, ..., 0.08847554, 0.0269705 ,
#          0.16116947]], dtype=float32),
#  'He wrote, "Notre Dame football is a spiritual service because it is played for the honor and glory of God and of his Blessed Mother.': array([[ 0.06277379,  0.07724059,  0.01295154, ...,  0.05302607,
#          -0.03814263,  0.08337726]], dtype=float32),
#  'The Rev.': array([[-0.00823845, -0.01287186, -0.00488612, ..., -0.03926745,
#          -0.03814263,  0.04989189]], dtype=float32),
#  'served as president from 1946 to 1952.': array([[ 0.06766412,  0.07666948, -0.01344291, ...,  0.00550244,
#          -0.03814263,  0.04005672]], dtype=float32),
#  "Cavanaugh also established the Lobund Institute for Animal Studies and Notre Dame's Medieval Institute.": array([[0.04595503, 0.18085103, 0.00296204, ..., 0.04491495, 0.07002208,
#          0.08191535]], dtype=float32),
#  "O'Shaughnessy, at the time the largest ever made to an American Catholic university.": array([[ 0.06543199,  0.06234345,  0.0337326 , ..., -0.01070259,
#           0.00311096,  0.0515505 ]], dtype=float32),
#  'Theodore Hesburgh, C.S.C., (1917–2015) served as president for 35 years (1952–87) of dramatic transformations.': array([[ 0.01931008,  0.11093277,  0.14359844, ...,  0.0745201 ,
#          -0.03814263,  0.07055233]], dtype=float32),
#  'Enrollment nearly doubled from 4,979 to 9,600, faculty more than doubled 389 to 950, and degrees awarded annually doubled from 1,212 to 2,500.': array([[ 0.06579036,  0.14039122,  0.05068083, ...,  0.1525027 ,
#          -0.01343169,  0.05342482]], dtype=float32),
#  "In the mid-1960s Notre Dame and Saint Mary's College developed a co-exchange program whereby several hundred students took classes not offered at their home institution, an arrangement that added undergraduate women to a campus that already had a few women in the graduate schools.": array([[0.05679357, 0.12984295, 0.13849987, ..., 0.1900107 , 0.02239984,
#          0.14721595]], dtype=float32),
#  '"In American college education," explained the Rev.': array([[ 0.04603221,  0.0568927 ,  0.02103966, ..., -0.01026006,
#           0.00336536,  0.10235219]], dtype=float32),
#  'In this environment of diversity, the integration of the sexes is a normal and expected aspect, replacing separatism."': array([[ 0.07354404,  0.14387901,  0.10684808, ...,  0.00177567,
#          -0.03814263, -0.00938571]], dtype=float32),
#  'Two of the male residence halls were converted for the newly admitted female students that first year, while two others were converted for the next school year.': array([[ 0.04415189,  0.12512757,  0.09457015, ...,  0.12012754,
#          -0.03613549,  0.07304241]], dtype=float32),
#  "In 1972 the first woman to graduate was Angela Sienko, who earned a bachelor's degree in marketing.": array([[ 0.03705068,  0.06701298,  0.15407176, ...,  0.06202826,
#          -0.0318257 ,  0.06860247]], dtype=float32),
#  'He increased the faculty by more than 500 professors; the academic quality of the student body has improved dramatically, with the average SAT score rising from 1240 to 1360; the number of minority students more than doubled; the endowment grew from $350 million to more than $3 billion; the annual operating budget rose from $177 million to more than $650 million; and annual research funding improved from $15 million to more than $70 million.': array([[0.00484726, 0.22407846, 0.17097491, ..., 0.10767597, 0.05755707,
#          0.0483338 ]], dtype=float32),
#  'capital campaign raised $1.1 billion, far exceeding its goal of $767 million, and is the largest in the history of Catholic higher education.': array([[ 0.0941508 ,  0.17709738,  0.04787471, ...,  0.08986648,
#          -0.02761957,  0.02110579]], dtype=float32),
#  'Jenkins took over the position from Malloy on July 1, 2005.': array([[ 0.03633657,  0.13416561,  0.02097631, ..., -0.00229221,
#          -0.03814263,  0.13596475]], dtype=float32),
#  'During his tenure, Notre Dame has increased its endowment, enlarged its student body, and undergone many construction projects on campus, including Compton Family Ice Arena, a new architecture hall, additional residence halls, and the Campus Crossroads, a $400m enhancement and expansion of Notre Dame Stadium.': array([[ 0.03873534,  0.10182872,  0.12051047, ...,  0.15493234,
#          -0.02062913,  0.06757957]], dtype=float32),
#  'The Old College building has become one of two seminaries on campus run by the Congregation of Holy Cross.': array([[0.05543946, 0.10943163, 0.03699373, ..., 0.22056   , 0.01305741,
#          0.05776515]], dtype=float32),
#  "Sorin's original church, which became too small for the growing college.": array([[ 0.02890818,  0.07164679,  0.05245361, ...,  0.0553876 ,
#          -0.03814263,  0.05734908]], dtype=float32),
#  'The interior was painted by Luigi Gregori, an Italian painter invited by Fr.': array([[ 0.0162687 ,  0.03136529,  0.12508588, ...,  0.00958115,
#          -0.01667224,  0.11475037]], dtype=float32),
#  'The Basilica also features a bell tower with a carillon.': array([[ 0.03948677,  0.03604314,  0.08008617, ...,  0.04408355,
#          -0.03814263, -0.01123235]], dtype=float32),
#  'The Grotto of Our Lady of Lourdes, which was built in 1896, is a replica of the original in Lourdes, France.': array([[ 0.06662107,  0.09150587,  0.07340924, ...,  0.05198732,
#          -0.03191261,  0.01575395]], dtype=float32),
#  'A Science Hall was built in 1883 under the direction of Fr.': array([[ 0.02386892,  0.12142924,  0.00531795, ..., -0.01585955,
#          -0.01577059,  0.08864821]], dtype=float32),
#  'Commonly known as "LaFortune" or "LaFun," it is a 4-story building of 83,000 square feet that provides the Notre Dame community with a meeting place for social, recreational, cultural, and educational activities.': array([[ 0.10811344,  0.07008804,  0.14671546, ...,  0.09106345,
#           0.00136015, -0.00176244]], dtype=float32),
#  'Many businesses, services, and divisions of The Office of Student Affairs are found within.': array([[ 0.10700738,  0.13544576,  0.0894899 , ...,  0.01525037,
#          -0.00414517, -0.02216317]], dtype=float32),
#  "Since the construction of its oldest buildings, the university's physical plant has grown substantially.": array([[ 0.07442981,  0.08651569,  0.11778126, ...,  0.141258  ,
#          -0.00958068,  0.02563993]], dtype=float32),
#  'Many academic building were added together with a system of libraries, the most prominent of which is the Theodore Hesburgh Library, built in 1963 and today containing almost 4 million books.': array([[ 0.03501282,  0.15590207,  0.08256978, ...,  0.15184462,
#          -0.00841576,  0.07729787]], dtype=float32),
#  'Additionally, a new residence for men, Duncan Hall, was begun on March 8, 2007, and began accepting residents for the Fall 2008 semester.': array([[ 0.0221439 ,  0.17553237,  0.09764034, ...,  0.05298838,
#          -0.0371806 ,  0.14018384]], dtype=float32),
#  'A new engineering building, Stinson-Remick Hall, a new combination Center for Social Concerns/Institute for Church Life building, Geddes Hall, and a law school addition have recently been completed as well.': array([[ 0.02713894,  0.10474962,  0.09443102, ...,  0.06490138,
#          -0.00631792,  0.07316974]], dtype=float32),
#  'The Stayer Center for Executive Education, which houses the Mendoza College of Business Executive Education Department opened in March 2013 just South of the Mendoza College of Business building.': array([[0.06301751, 0.16301559, 0.09110464, ..., 0.05456087, 0.03897034,
#          0.06544852]], dtype=float32),
#  'The most famous is Notre Dame Stadium, home of the Fighting Irish football team; it has been renovated several times and today it can hold more than 80 thousand people.': array([[ 0.11621756,  0.07817855,  0.08812308, ...,  0.09842462,
#           0.01168687, -0.0005038 ]], dtype=float32),
#  'Also, there are many outdoor fields, as the Frank Eck Stadium for baseball.': array([[ 0.03906001,  0.02614195,  0.01173174, ...,  0.02340934,
#          -0.03814263,  0.08258323]], dtype=float32),
#  "Notre Dame's dining services sources 40% of its food locally and offers sustainably caught seafood as well as many organic, fair-trade, and vegan options.": array([[ 0.13348682,  0.17265458,  0.10764081, ...,  0.16935173,
#          -0.02449151,  0.05168424]], dtype=float32),
#  'The university also houses the Kroc Institute for International Peace Studies.': array([[0.0255609 , 0.13583988, 0.01694169, ..., 0.09086644, 0.05685036,
#          0.06573813]], dtype=float32),
#  'The university owns several centers around the world used for international studies and research, conferences abroad, and alumni support.': array([[0.11882681, 0.03462589, 0.02013309, ..., 0.13921776, 0.08474135,
#          0.06928594]], dtype=float32),
#  'Since 1998, its London center has been based in the former United University Club at 1 Suffolk Street in Trafalgar Square.': array([[ 0.08540458,  0.11450201,  0.04511619, ...,  0.06799316,
#          -0.03814263,  0.12365723]], dtype=float32),
#  'Other Global Gateways are located in Beijing, Chicago, Dublin, Jerusalem and Rome.': array([[0.17580348, 0.16135988, 0.03391849, ..., 0.00470168, 0.03234316,
#          0.01815318]], dtype=float32),
#  "The university's first academic curriculum was modeled after the Jesuit Ratio Studiorum from Saint Louis University.": array([[0.03664797, 0.05448456, 0.06585374, ..., 0.07594344, 0.01224848,
#          0.14972273]], dtype=float32),
#  "degrees in 33 majors, making it the largest of the university's colleges.": array([[0.11257175, 0.12999994, 0.02779438, ..., 0.0839128 , 0.03276699,
#          0.01768501]], dtype=float32),
#  'The College of Science was established at the university in 1865 by president Father Patrick Dillon.': array([[ 0.02333842,  0.16331045,  0.01388627, ...,  0.05684906,
#          -0.00190077,  0.12260669]], dtype=float32),
#  'Today the college, housed in the newly built Jordan Hall of Science, includes over 1,200 undergraduates in six departments of study – biology, chemistry, mathematics, physics, pre-professional studies, and applied and computational mathematics and statistics (ACMS) – each awarding Bachelor of Science (B.S.)': array([[0.08357788, 0.16261037, 0.07832608, ..., 0.24789816, 0.05113447,
#          0.12462278]], dtype=float32),
#  'According to university statistics, its science pre-professional program has one of the highest acceptance rates to medical school of any university in the United States.': array([[ 0.11710839,  0.0825742 ,  0.10988446, ...,  0.1069198 ,
#           0.06400672, -0.00351118]], dtype=float32),
#  'Today the school, housed in Bond Hall, offers a five-year undergraduate program leading to the Bachelor of Architecture degree.': array([[0.07531738, 0.13006368, 0.03950734, ..., 0.1383242 , 0.04551465,
#          0.09095441]], dtype=float32),
#  'The university is globally recognized for its Notre Dame School of Architecture, a faculty that teaches (pre-modernist) traditional and classical architecture and urban planning (e.g.': array([[0.1380027 , 0.07385352, 0.10720178, ..., 0.11001419, 0.00518357,
#          0.11133577]], dtype=float32),
#  'It also awards the renowned annual Driehaus Architecture Prize.': array([[0.06003062, 0.1736741 , 0.01116859, ..., 0.12063029, 0.00679303,
#          0.03907664]], dtype=float32),
#  'A theology library was also opened in fall of 2015.': array([[ 0.05080223,  0.12340768,  0.06474344, ...,  0.00841986,
#          -0.01164579,  0.12467895]], dtype=float32),
#  'The library system holds over three million volumes, was the single largest university library in the world upon its completion, and remains one of the 100 largest libraries in the country.': array([[0.10897013, 0.17608957, 0.02101632, ..., 0.2278482 , 0.05933761,
#          0.02221035]], dtype=float32),
#  'From Germany came Anton-Hermann Chroust (1907–1982) in classics and law, and Waldemar Gurian a German Catholic intellectual of Jewish descent.': array([[ 0.09118293,  0.07745502,  0.10772008, ...,  0.00857184,
#          -0.03814263,  0.007788  ]], dtype=float32),
#  'Ivan Meštrović (1883–1962), a renowned sculptor, brought Croatian culture to campus, 1955–62.': array([[ 0.07522357,  0.07578848,  0.04310836, ..., -0.02814944,
#          -0.01726813,  0.01953014]], dtype=float32),
#  'The University of Notre Dame du Lac (or simply Notre Dame /ˌnoʊtərˈdeɪm/ NOH-tər-DAYM) is a Catholic research university located adjacent to South Bend, Indiana, in the United States.': array([[0.11813845, 0.12176369, 0.09333622, ..., 0.07422125, 0.02390101,
#          0.10378063]], dtype=float32),
#  'The main campus covers 1,250 acres in a suburban setting and it contains a number of recognizable landmarks, such as the Golden Dome, the "Word of Life" mural (commonly known as Touchdown Jesus), and the Basilica.': array([[ 0.07290702,  0.10461047,  0.14551795, ...,  0.12739499,
#          -0.03814263,  0.08357434]], dtype=float32),
#  "The university's athletic teams are members of the NCAA Division I and are known collectively as the Fighting Irish.": array([[ 0.02420577,  0.126008  ,  0.04344451, ..., -0.03926745,
#          -0.03814263, -0.01019451]], dtype=float32),
#  'Other ND teams, chiefly in the Atlantic Coast Conference, have accumulated 16 national championships.': array([[ 0.13232902,  0.25966543,  0.00458682, ...,  0.03297774,
#          -0.03814263,  0.04419776]], dtype=float32),
#  'Besides its prominence in sports, Notre Dame is also a large, four-year, highly residential research University, and is consistently ranked among the top twenty universities in the United States  and as a major global university.': array([[0.12833047, 0.13103685, 0.10897942, ..., 0.18339194, 0.05245439,
#          0.10665669]], dtype=float32),
#  'The latter is known for teaching New Classical Architecture and for awarding the globally renowned annual Driehaus Architecture Prize.': array([[0.07984031, 0.14607318, 0.04395731, ..., 0.10818452, 0.00741381,
#          0.11607755]], dtype=float32),
#  'It maintains a system of libraries, cultural venues, artistic and scientific museums, including Hesburgh Library and the Snite Museum of Art.': array([[0.08062281, 0.11640288, 0.10788662, ..., 0.1033503 , 0.00710323,
#          0.04709537]], dtype=float32),
#  'The university counts approximately 120,000 alumni, considered among the strongest alumni networks among U.S. colleges.': array([[ 0.06617387,  0.13689035,  0.06296565, ...,  0.1398218 ,
#          -0.01789174,  0.0449777 ]], dtype=float32),
#  'Fr.': array([[ 0.0137414 , -0.06433091, -0.01686102, ..., -0.03926745,
#          -0.03814263,  0.05829942]], dtype=float32),
#  'He soon erected additional buildings, including Old College, the first church, and the first main building.': array([[ 0.0499821 ,  0.08077513,  0.06283436, ...,  0.15409341,
#          -0.02031372,  0.08544271]], dtype=float32),
#  'The first degrees from the college were awarded in 1849.': array([[ 0.02282235,  0.07822035,  0.04398549, ...,  0.09922571,
#          -0.03814263,  0.00417926]], dtype=float32),
#  'With each new president, new academic programs were offered and new buildings built to accommodate them.': array([[0.07738242, 0.09821969, 0.06523705, ..., 0.08120348, 0.05927285,
#          0.02439448]], dtype=float32),
#  'Beginning in 1873, a library collection was started by Father Lemonnier.': array([[ 0.07644197,  0.06376495,  0.06152072, ...,  0.04476593,
#          -0.00764293,  0.08124448]], dtype=float32),
#  'The television station, NDtv, grew from one show in 2002 to a full 24-hour channel with original programming by September 2006.': array([[ 0.1151138 ,  0.07555791,  0.02657494, ...,  0.11903937,
#          -0.03814263,  0.06696353]], dtype=float32),
#  'Another radio station, WVFI, began as a partner of WSND-FM.': array([[ 0.07762063,  0.09160573,  0.02132367, ..., -0.03391256,
#          -0.03814263,  0.02925508]], dtype=float32),
#  'The first phase of Eddy Street Commons, a $215 million development located adjacent to the University of Notre Dame campus and funded by the university, broke ground on June 3, 2008.': array([[0.06643088, 0.1744453 , 0.14106737, ..., 0.10136954, 0.02060833,
#          0.09237554]], dtype=float32),
#  'The developer, Kite Realty out of Indianapolis, has made agreements with major national chains rather than local businesses, a move that has led to criticism from alumni and students.': array([[ 0.06522447,  0.12767628,  0.02175671, ...,  0.0656474 ,
#          -0.01518387,  0.03581899]], dtype=float32),
#  'They compete as a member of the National Collegiate Athletic Association (NCAA) Division I, primarily competing in the Atlantic Coast Conference (ACC) for all sports since the 2013–14 school year.': array([[ 0.11987764,  0.24431191,  0.10974403, ...,  0.05461748,
#          -0.03613549,  0.04457074]], dtype=float32),
#  "Men's sports include baseball, basketball, crew, cross country, fencing, football, golf, ice hockey, lacrosse, soccer, swimming & diving, tennis and track & field; while women's sports include basketball, cross country, fencing, golf, lacrosse, rowing, soccer, softball, swimming & diving, tennis, track & field and volleyball.": array([[ 0.11110069,  0.11289265,  0.10048152, ..., -0.00546683,
#          -0.03814263,  0.04000697]], dtype=float32),
#  "Both fencing teams compete in the Midwest Fencing Conference, and the men's ice hockey team competes in Hockey East.": array([[ 0.12353783,  0.14542986,  0.06939948, ..., -0.03926745,
#          -0.03814263,  0.04539951]], dtype=float32),
#  'The Irish left the Big East for the ACC during a prolonged period of instability in the Big East; while they maintain their football independence, they have committed to play five games per season against ACC opponents.': array([[ 0.12174753,  0.16088453,  0.11970493, ...,  0.13901028,
#          -0.03814263,  0.08303457]], dtype=float32),
#  'Notre Dame moved its hockey team to Hockey East.': array([[ 0.06692616,  0.05096044,  0.00492016, ..., -0.03926745,
#          -0.03814263,  0.04349275]], dtype=float32),
#  'There are many theories behind the adoption of the athletics moniker but it is known that the Fighting Irish name was used in the early 1920s with respect to the football team and was popularized by alumnus Francis Wallace in his New York Daily News columns.': array([[ 0.07629772,  0.12997286,  0.08575828, ...,  0.0843726 ,
#          -0.01694666,  0.15341628]], dtype=float32),
#  'In addition, the color green is often worn because of the Fighting Irish nickname.': array([[ 0.07094026,  0.33017322,  0.2608485 , ..., -0.03926745,
#          -0.03814263, -0.0127018 ]], dtype=float32),
#  'Created by Theodore W. Drake in 1964, the leprechaun was first used on the football pocket schedule and later on the football program covers.': array([[ 0.08626005,  0.11839536,  0.08524019, ...,  0.08247453,
#          -0.02831907,  0.13304944]], dtype=float32),
#  'On July 1, 2014, the University of Notre Dame and Under Armour reached an agreement in which Under Armour will provide uniforms, apparel,equipment, and monetary compensation to Notre Dame for 10 years.': array([[ 0.08101976,  0.17876849,  0.06821547, ...,  0.16656911,
#          -0.03286854,  0.09165723]], dtype=float32),
#  'The university marching band plays at home games for most of the sports.': array([[ 0.10075869,  0.05974762,  0.03611197, ...,  0.01650221,
#          -0.03814263, -0.00086361]], dtype=float32),
#  "The band regularly plays the school's fight song the Notre Dame Victory March, which was named as the most played and most famous fight song by Northern Illinois Professor William Studwell.": array([[ 0.1014037 ,  0.1073156 ,  0.07706909, ...,  0.05551593,
#          -0.03814263,  0.19159319]], dtype=float32),
#  'The Notre Dame football team has a long history, first beginning when the Michigan Wolverines football team brought football to Notre Dame in 1887 and played against a group of students.': array([[ 0.06221268,  0.09799745,  0.03758377, ...,  0.07240654,
#          -0.03814263,  0.11015223]], dtype=float32),
#  'Additionally, the program has the most members in the College Football Hall of Fame, is tied with Ohio State University with the most Heisman Trophies won, and have the highest winning percentage in NCAA history.': array([[ 0.04254412,  0.12484381,  0.07683595, ...,  0.09369211,
#          -0.03814263,  0.09847476]], dtype=float32),
#  "George Gipp was the school's legendary football player during 1916–20.": array([[ 0.05015673,  0.02518428,  0.03812781, ...,  0.00406123,
#          -0.03814263,  0.13265069]], dtype=float32),
#  'He was also humble, generous to the needy, and a man of integrity.': array([[ 0.02934745,  0.07243943,  0.07967094, ..., -0.03926745,
#          -0.03814263,  0.02163427]], dtype=float32),
#  "The 1940 film, Knute Rockne, All American, starred Pat O'Brien as Knute Rockne and Ronald Reagan as Gipp.": array([[ 0.07479234,  0.03377649,  0.04850629, ..., -0.03926745,
#          -0.03814263,  0.1757873 ]], dtype=float32),
#  'The current head coach is Brian Kelly, hired from the University of Cincinnati on December 11, 2009.': array([[0.05599232, 0.10155433, 0.04090419, ..., 0.02848115, 0.00483832,
#          0.17143375]], dtype=float32),
#  "In 2012, Kelly's Fighting Irish squad went undefeated and played in the BCS National Championship Game.": array([[ 0.07084587,  0.12036138,  0.04085495, ..., -0.03926745,
#          -0.03814263,  0.10418504]], dtype=float32),
#  'Although Weis led his team to two Bowl Championship Series bowl games, his overall record was 35–27, mediocre by Notre Dame standards, and the 2007 team had the most losses in school history.': array([[ 0.03778902,  0.11687247,  0.05299827, ...,  0.03393568,
#          -0.02299801,  0.05056929]], dtype=float32),
#  'Forbes named the team as the most valuable in college football, worth a total of $101 million in 2007.': array([[ 0.11439914,  0.16843933,  0.05739937, ...,  0.08312333,
#          -0.03814263,  0.01583305]], dtype=float32),
#  "Zahm House's two-story banner).": array([[ 0.03946222,  0.12336893,  0.08233879, ...,  0.07354549,
#          -0.02773892, -0.00848599]], dtype=float32),
#  'This tradition involves the drum line of the Band of the Fighting Irish and ushers in the rest of the festivities that will continue the rest of the gameday Saturday.': array([[ 0.05539125,  0.10008746,  0.05084461, ...,  0.04318195,
#          -0.03814263,  0.04443827]], dtype=float32),
#  'The band entire will play a concert at the steps of Bond Hall, from where they will march into Notre Dame Stadium, leading fans and students alike across campus to the game.': array([[0.08771913, 0.07411718, 0.11588234, ..., 0.06730063, 0.03642771,
#          0.0649773 ]], dtype=float32),
#  'Former player Austin Carr holds the record for most points scored in a single game of the tournament with 61.': array([[ 0.09797028,  0.08987359,  0.04232933, ...,  0.04752069,
#          -0.03814263,  0.14616299]], dtype=float32),
#  "The team has orchestrated a number of upsets of number one ranked teams, the most notable of which was ending UCLA's record 88-game winning streak in 1974.": array([[ 0.0617972 ,  0.14168827,  0.07084273, ...,  0.08632236,
#          -0.03814263,  0.07336196]], dtype=float32),
#  'The team plays in newly renovated Purcell Pavilion (within the Edmund P. Joyce Center), which reopened for the beginning of the 2009–2010 season.': array([[ 0.10039943,  0.07980444,  0.04641416, ...,  0.06605763,
#          -0.01262316,  0.12941918]], dtype=float32),
#  'In 2009 they were invited to the NIT, where they advanced to the semifinals but were beaten by Penn State who went on and beat Baylor in the championship.': array([[ 0.03735726,  0.08127287,  0.07346367, ..., -0.03926745,
#          -0.03814263,  0.0877379 ]], dtype=float32),
#  'During the 2014-15 season, the team went 32-6 and won the ACC conference tournament, later advancing to the Elite 8, where the Fighting Irish lost on a missed buzzer-beater against then undefeated Kentucky.': array([[ 0.05218672,  0.14563808,  0.07967102, ...,  0.00705566,
#          -0.03814263,  0.05070091]], dtype=float32),
#  'The 32 wins were the most by the Fighting Irish team since 1908-09.': array([[ 0.06034819,  0.10640215,  0.05153524, ...,  0.05791653,
#          -0.03814263, -0.02052868]], dtype=float32),
#  'It was written by two brothers who were Notre Dame graduates.': array([[ 0.01451322,  0.07462198,  0.01009989, ...,  0.09573399,
#          -0.03814263,  0.14904128]], dtype=float32),
#  'The lyrics were revised in the 1920s; it first appeared under the copyright of the University of Notre Dame in 1928.': array([[0.04543864, 0.10775908, 0.1113482 , ..., 0.06373199, 0.00085608,
#          0.09820912]], dtype=float32),
#  'Send a volley cheer on high, shake down the thunder from the sky!': array([[ 0.04668337,  0.03763687,  0.05425229, ..., -0.02498932,
#          -0.0295556 , -0.02228739]], dtype=float32),
#  'While her loyal sons are marching, onward to victory!"': array([[ 0.04128716,  0.02034344,  0.01873465, ...,  0.06549764,
#          -0.03814263,  0.06947792]], dtype=float32),
#  'George Gipp was played by Ronald Reagan, whose nickname "The Gipper" was derived from this role.': array([[ 0.04144514,  0.01632231,  0.1074378 , ...,  0.00615941,
#          -0.03814263,  0.14011821]], dtype=float32),
#  "with the same background music, only this time honoring George Zipp, one of Ted Striker's former comrades.": array([[ 0.04744201,  0.09647638,  0.00096084, ...,  0.01696916,
#          -0.03814263,  0.10505036]], dtype=float32),
#  'Notre Dame alumni work in various fields.': array([[ 0.05104876,  0.05096044,  0.02618459, ...,  0.0818835 ,
#          -0.03437493,  0.02040756]], dtype=float32),
#  'A notable alumnus of the College of Science is Medicine Nobel Prize winner Eric F. Wieschaus.': array([[ 0.0365419 ,  0.1465604 ,  0.03939555, ...,  0.01229278,
#          -0.01183553,  0.14669164]], dtype=float32),
#  'John Jenkins.': array([[ 0.00716   ,  0.0721748 , -0.01799673, ..., -0.03926745,
#          -0.03814263,  0.18168938]], dtype=float32),
#  'With the university having high profile sports teams itself, a number of alumni went on to become involved in athletics outside the university, including professional baseball, basketball, football, and ice hockey players, such as Joe Theismann, Joe Montana, Tim Brown, Ross Browner, Rocket Ismail, Ruth Riley, Jeff Samardzija, Jerome Bettis, Brett Lebda, Olympic gold medalist Mariel Zagunis, professional boxer Mike Lee, former football coaches such as Charlie Weis, Frank Leahy and Knute Rockne, and Basketball Hall of Famers Austin Carr and Adrian Dantley.': array([[ 0.05212848,  0.1596938 ,  0.10795338, ...,  0.10374585,
#          -0.03814263,  0.19522978]], dtype=float32),
#  'Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress.': array([[ 0.06352398,  0.1739728 ,  0.10705583, ...,  0.05814757,
#          -0.03814263,  0.1480674 ]], dtype=float32),
#  "Managed by her father, Mathew Knowles, the group became one of the world's best-selling girl groups of all time.": array([[ 0.07904933,  0.10293279,  0.08753081, ...,  0.04002655,
#          -0.03814263,  0.1748905 ]], dtype=float32),
# ...
#          -0.03814263,  0.08890674]], dtype=float32),
#  'Beyonce does not create which aspect of her music?': array([[ 0.06155975,  0.12192027,  0.05813828, ...,  0.08019597,
#          -0.03814263,  0.00508096]], dtype=float32),
#  "What theme was Beyonce's early music?": array([[ 0.02285765,  0.05756742,  0.05578954, ..., -0.0009034 ,
#          -0.03814263,  0.04116147]], dtype=float32),
#  'What does she get credits for in her music?': array([[ 0.03483973,  0.12262308,  0.00084085, ...,  0.08019597,
#          -0.03814263,  0.01314812]], dtype=float32),
#  "Beyoncé's early recordings empowered who?": array([[ 0.05588757,  0.04436309,  0.04046684, ..., -0.03845022,
#          -0.03814263,  0.00471052]], dtype=float32),
#  'Rather than beats, what two things does Beyoncé usually come up with for producers?': array([[ 0.0323918 ,  0.09862377,  0.12274095, ...,  0.05815721,
#          -0.03814263,  0.11059966]], dtype=float32),
#  'Beyonce received the Pop Songwriter of the Year award at which event?': array([[ 0.045033  ,  0.1075872 ,  0.05813828, ..., -0.00130759,
#          -0.03814263,  0.06279402]], dtype=float32),
#  'Beyonce joined 2 other women on what list from Billboard magazine in 2011?': array([[ 0.10689017,  0.15536278,  0.14208195, ...,  0.1118848 ,
#          -0.03814263,  0.10568628]], dtype=float32),
#  'What place is she tied for in songwriting credits?': array([[ 0.09271739,  0.1194722 ,  0.0209511 , ...,  0.1147707 ,
#          -0.03814263,  0.03201916]], dtype=float32),
#  'Where does she place in writing credits  for three number one songs?': array([[ 0.12078838,  0.19025554,  0.01501107, ...,  0.24240649,
#          -0.03814263, -0.00046158]], dtype=float32),
#  'Who gave Beyoncé the Pop Songwriter of the Year award in 2001?': array([[ 0.06275748,  0.1086837 ,  0.01913869, ...,  0.01610361,
#          -0.03031014,  0.05980133]], dtype=float32),
#  'What number was Beyoncé on the Top 20 Hot 100 Songwriters list?': array([[ 0.1219614 ,  0.12893803,  0.08521575, ...,  0.06903622,
#          -0.03097082,  0.05798269]], dtype=float32),
#  'How old was Beyonce when she went to her first Michael Jackson concert as a kid?': array([[ 0.00744847,  0.04068198,  0.07122989, ...,  0.04492257,
#          -0.03814263,  0.1517562 ]], dtype=float32),
#  'Beyonce cites Mariah Carey to making her want to start doing what?': array([[ 0.05434791,  0.01220122,  0.05813828, ..., -0.01478834,
#          -0.03814263,  0.09333892]], dtype=float32),
#  'What song by Mariah Carey influenced her?': array([[ 0.07517788, -0.02702277,  0.03705198, ...,  0.05456857,
#          -0.03814263,  0.11762501]], dtype=float32),
#  "What was Beyoncé's first concert?": array([[ 0.01769488,  0.09283944,  0.03410972, ...,  0.03627885,
#          -0.03814263,  0.04750583]], dtype=float32),
#  'Who does she credit for the inspiration to "get up there and do what she did"?': array([[ 0.02751765,  0.066764  ,  0.0261919 , ..., -0.03529892,
#          -0.03535667,  0.01968703]], dtype=float32),
#  'What themes were influenced by her acting role in Dreamgirls?': array([[ 0.09912159,  0.0347808 ,  0.07706296, ...,  0.04823452,
#          -0.03814263,  0.06184014]], dtype=float32),
#  'Who motivated Beyonce to explore other areas of music?': array([[ 0.13451292,  0.10079137,  0.05813828, ...,  0.04557423,
#          -0.03814263, -0.00447433]], dtype=float32),
#  'How did Etta James influence her?': array([[ 0.03548583,  0.02223007, -0.00484222, ...,  0.05456857,
#          -0.03814263,  0.1508851 ]], dtype=float32),
#  "What singer inspired Beyoncé's B'Day album?": array([[ 0.11538151,  0.06207198,  0.10172635, ...,  0.06808238,
#          -0.03814263,  0.07912154]], dtype=float32),
#  'Beyonce has noted which first lady with saying "She proves you can do it all"?': array([[ 0.10431454,  0.08251396,  0.06698734, ..., -0.00568978,
#          -0.03814263,  0.03605125]], dtype=float32),
#  'Beyonce has said that who embodies the "definition of inspiration and a strong woman"?': array([[ 0.10431454,  0.10072146,  0.14134644, ..., -0.02535797,
#          -0.03814263,  0.05420734]], dtype=float32),
#  'Hoe does she describe Oprah Winfrey?': array([[ 0.07966815, -0.02907046,  0.0519687 , ...,  0.03015651,
#          -0.03814263,  0.16127336]], dtype=float32),
#  'How does Madonna influence her?': array([[ 0.05100385, -0.02169718,  0.02266998, ...,  0.05456857,
#          -0.03814263,  0.00842992]], dtype=float32),
#  'Who inspires Beyoncé because "she does it all?"': array([[ 0.05458341, -0.04488941,  0.0410324 , ..., -0.00731821,
#          -0.03814263, -0.01592969]], dtype=float32),
#  'Who does Beyoncé describe as lyrical and raw?': array([[ 0.03868961,  0.09349263,  0.08248305, ...,  0.01649372,
#          -0.03814263, -0.00493195]], dtype=float32),
#  'Beyonce had an all-female tour band whose name was what?': array([[ 0.09660882,  0.00144166,  0.05813828, ...,  0.07207683,
#          -0.03814263,  0.015695  ]], dtype=float32),
#  'The Mamas members included which 3 musicians?': array([[-0.00823845,  0.17065623,  0.005904  , ...,  0.0687481 ,
#          -0.03814263,  0.00627142]], dtype=float32),
#  'What band did Beyonce introduce in 2006?': array([[ 0.11648609,  0.06366414,  0.02216995, ...,  0.01076676,
#          -0.0369232 ,  0.02329284]], dtype=float32),
#  'Where did Suga Mama band make their first appearance?': array([[ 0.09011796,  0.0583582 ,  0.17326888, ...,  0.12529051,
#          -0.03814263,  0.15473998]], dtype=float32),
#  "What is the name of Beyoncé's female tour band?": array([[ 0.09005939,  0.08806179,  0.09945524, ...,  0.05862538,
#          -0.03814263,  0.015788  ]], dtype=float32),
#  "What are Beyoncé's backup singers called?": array([[ 0.10205365,  0.08571168,  0.03785935, ...,  0.04003722,
#          -0.03814263,  0.05137439]], dtype=float32),
#  'What characteristics has Beyonce received acclaim for?': array([[ 0.07748441,  0.05345876,  0.08925914, ...,  0.00476143,
#          -0.03814263,  0.0372971 ]], dtype=float32),
#  'For what does Beyonce receive praise?': array([[ 0.02362951,  0.01093761,  0.0105919 , ..., -0.03926745,
#          -0.03814263,  0.02943469]], dtype=float32),
#  'How has L.A. Reid described her?': array([[ 0.07203596,  0.11917212,  0.0810512 , ...,  0.05456857,
#          -0.03814263,  0.11072291]], dtype=float32),
#  'Who has Beyoncé at number one on her Five Best Singer/Dancers?': array([[ 0.08070107,  0.15173897,  0.08015274, ...,  0.12371215,
#          -0.03814263, -0.01206912]], dtype=float32),
#  'Beyonce self proclaimed alter ego is named what?': array([[ 0.08787034,  0.05592561,  0.12884709, ..., -0.03926745,
#          -0.03814263,  0.06044157]], dtype=float32),
#  'What year did Beyonce do away with Sasha Fierce?': array([[ 0.02561213,  0.0105283 ,  0.0128406 , ..., -0.03926745,
#          -0.03814263,  0.02401301]], dtype=float32),
#  'How does she describe Sasha?': array([[ 0.03352971, -0.07579605,  0.04533348, ..., -0.03926745,
#          -0.03814263,  0.0001029 ]], dtype=float32),
#  "What is the name of Beyoncé's alter ego?": array([[ 0.0711433 ,  0.08806179,  0.14785965, ..., -0.03926745,
#          -0.03814263,  0.02193017]], dtype=float32),
#  'Sasha Fierce was created during the making of what song?': array([[ 0.05467916,  0.11067145,  0.04450604, ...,  0.02355252,
#          -0.03814263,  0.0149818 ]], dtype=float32),
#  "Beyonce's sex appeal is characterized as what?": array([[ 0.0996123 ,  0.04157273,  0.08426556, ..., -0.03926745,
#          -0.03814263,  0.02356564]], dtype=float32),
#  'Which word spawned from a term used to describe Beyonce in 2006?': array([[ 0.11571842,  0.06135129,  0.15400344, ..., -0.02498823,
#           0.00954464, -0.00612003]], dtype=float32),
#  'Oxford Dictionary added which word from the 2000s dedicated to Beyonce?': array([[ 0.06000565,  0.0671211 ,  0.09024242, ..., -0.03691579,
#          -0.03814263,  0.12558258]], dtype=float32),
#  'When was the term added to the dictionary?': array([[-0.00027109,  0.07208576,  0.09787033, ..., -0.02413291,
#          -0.02950405,  0.04477119]], dtype=float32),
#  "Because of Beyoncé's physical shape, what slang term has been used to describe her?": array([[0.03740185, 0.08901186, 0.11231587, ..., 0.05456857, 0.02398502,
#          0.00813025]], dtype=float32),
#  'How does Beyoncé say she likes to dress off-stage?': array([[ 0.10003688,  0.01511567,  0.11810691, ..., -0.03926745,
#          -0.03814263,  0.03252299]], dtype=float32),
#  "Beyonce's first modelling event was at where?": array([[ 0.06108124,  0.08317185,  0.07306486, ..., -0.01872106,
#          -0.01744063,  0.03934802]], dtype=float32),
#  'Which month and year did GQ feature Beyonce on its cover?': array([[ 0.08213418,  0.05879879,  0.11483096, ...,  0.06928719,
#          -0.01868277,  0.04029869]], dtype=float32),
#  "Who called Beyonce the World's most Beautiful Woman?": array([[ 0.09150635,  0.08059996,  0.08968748, ..., -0.03926745,
#          -0.03571479,  0.01862172]], dtype=float32),
#  'When did she appear on the cover of GQ?': array([[ 0.10606073,  0.10309894,  0.1205259 , ...,  0.01464846,
#          -0.02821865,  0.05068871]], dtype=float32),
#  'What year did Beyoncé first model for Tom Ford?': array([[0.01607771, 0.11415868, 0.01576276, ..., 0.00018033, 0.02060447,
#          0.07439412]], dtype=float32),
#  'What title did Complex award Beyoncé?': array([[ 0.04267802,  0.06721956,  0.0085532 , ...,  0.00306741,
#          -0.01749551,  0.02815805]], dtype=float32),
#  "Which parent of Beyonce's help co-write a book?": array([[ 0.02992805,  0.09764873,  0.03635091, ...,  0.02545521,
#          -0.03020594,  0.01528552]], dtype=float32),
#  "What was the title of Beyonce's mother's book?": array([[ 0.0087881 ,  0.12420932,  0.05645711, ...,  0.01390121,
#          -0.03814263,  0.07608608]], dtype=float32),
#  'Who was she the second  African American on the cover after?': array([[ 0.09635293,  0.12139767,  0.16276416, ...,  0.03715299,
#          -0.03814263,  0.01060138]], dtype=float32),
#  'What magazine said Beyoncé was the "best-dressed celebrity"?': array([[ 0.13830195,  0.07553345,  0.21164268, ..., -0.01447876,
#          -0.03814263,  0.07725216]], dtype=float32),
#  'Before the Bey Hive, fans of Beyonce were called what?': array([[ 0.04532693,  0.09408997,  0.05366902, ..., -0.00512124,
#          -0.03814263,  0.04025112]], dtype=float32),
#  "What is Beyonce's fan base called?": array([[ 0.0711433 ,  0.122476  ,  0.05328809, ...,  0.00124884,
#          -0.03814263,  0.02841388]], dtype=float32),
#  'What is the latest term used to describe Beyoncé fans?': array([[ 0.0711433 ,  0.05411833,  0.12123277, ..., -0.03926745,
#          -0.01154652, -0.00056626]], dtype=float32),
#  'What word does "Bey Hive" derive from?': array([[ 0.03879603,  0.00287843,  0.01937438, ..., -0.03926745,
#          -0.03814263,  0.03522309]], dtype=float32),
#  'Which French magazine did Beyonce show up on the cover of?': array([[ 0.12514506,  0.0897549 ,  0.08849717, ...,  0.10984543,
#          -0.03814263,  0.06859922]], dtype=float32),
#  'Which year did PETA spark controversy with Beyonce?': array([[ 0.04613896,  0.0468579 ,  0.05780606, ..., -0.01733931,
#          -0.03814263,  0.0179559 ]], dtype=float32),
#  'What French Magazine cover did the media criticize?': array([[ 0.11844037,  0.09956841,  0.07528457, ..., -0.02744151,
#          -0.03814263,  0.03557977]], dtype=float32),
#  'What French magazine did Beyoncé appear in wearing blackface and tribal makeup?': array([[ 0.12871297,  0.07525248,  0.21617514, ...,  0.01342734,
#          -0.03814263,  0.04304448]], dtype=float32),
#  "What type of magazine is L'Officiel?": array([[ 0.09156412,  0.11179343,  0.09522227, ..., -0.03926745,
#          -0.03814263, -0.00557829]], dtype=float32),
#  'Which professor from Northeastern University wrote about how race correlates with these criticisms of Beyonce?': array([[0.02543979, 0.16795939, 0.0844995 , ..., 0.03423365, 0.01129859,
#          0.13040787]], dtype=float32),
#  'What did Vogue request?': array([[ 0.05247908, -0.00189985,  0.03913592, ..., -0.03926745,
#          -0.03175057,  0.03490105]], dtype=float32),
#  'In addition to her light skin color, what else has made part of the African American community criticize Beyoncé?': array([[ 6.2767312e-02,  1.4999400e-01,  1.3925870e-01, ...,
#           5.6386963e-02, -3.8142629e-02,  5.8261863e-05]], dtype=float32),
#  "Who was accused of lightening Beyoncé's skin for an advertisement?": array([[ 0.05819877,  0.13545045,  0.17739405, ...,  0.02135594,
#          -0.00798675,  0.02576066]], dtype=float32),
#  'Who did Beyoncé tell in 2013 to only use natural pictures of her rather than retouched images?': array([[ 0.1150241 ,  0.12353834,  0.06738967, ...,  0.07254335,
#          -0.03814263,  0.0311656 ]], dtype=float32),
#  'Whats the first year that Beyonce appear on the Time 100 list?': array([[ 0.09092803,  0.07870548,  0.15359859, ...,  0.09336974,
#          -0.03097082,  0.07554677]], dtype=float32),
#  'What did the Guardian name her?': array([[ 0.09503115,  0.03045243,  0.00173996, ...,  0.05456857,
#          -0.03814263,  0.0362701 ]], dtype=float32),
#  'When was she again on the Time 100 List and on the cover?': array([[0.05752843, 0.07714284, 0.05086645, ..., 0.07831527, 0.04050874,
#          0.06483968]], dtype=float32),
#  'Who stated that Beyoncé is the most important musician of the 21st century?': array([[ 0.0637742 ,  0.07626865,  0.11206818, ..., -0.00592596,
#          -0.03814263,  0.01669717]], dtype=float32),
#  'What list did Beyoncé make in 2013?': array([[ 0.11933576,  0.12988639,  0.07039035, ..., -0.01529614,
#          -0.02194924,  0.03241042]], dtype=float32),
#  'What year was Beyoncé featured both on the Time 100 list as well as the cover of the issue?': array([[ 0.09125891,  0.11303513,  0.08055782, ...,  0.05370653,
#          -0.03814263,  0.07382466]], dtype=float32),
#  'Which friend learned from Beyonce while preparing for the film, "Country Strong?"': array([[ 0.0732571 ,  0.07369748,  0.03651363, ..., -0.01298188,
#          -0.03814263,  0.05987946]], dtype=float32),
#  'What influenced Nicki Minaj to join the Pepsi global campaign?': array([[ 0.12529479,  0.08527883,  0.11934908, ..., -0.02706081,
#          -0.00703115,  0.13102716]], dtype=float32),
#  'What about Beyonce has influenced many entertainers?': array([[ 0.12491711,  0.00445674,  0.11209305, ...,  0.04426413,
#          -0.03814263,  0.04141818]], dtype=float32),
#  'Which Indie band said Beyoncé was an inspiration for one of hteir albums?': array([[ 0.08344612,  0.09657479,  0.06131423, ...,  0.10529494,
#          -0.03814263,  0.06813914]], dtype=float32),
#  "Who studied Beyoncé during live concerts for research for a film's music role?": array([[0.12546572, 0.08345158, 0.08826979, ..., 0.09910484, 0.03252959,
#          0.13734794]], dtype=float32),
#  "Beyoncé's Pepsi commercial inspired which star to join Pepsi's global campaign in 2012?": array([[ 0.1189722 ,  0.10887252,  0.07265839, ..., -0.01504379,
#           0.00392227,  0.02623568]], dtype=float32),
#  'How many Grammy awards did "Crazy in Love" win?': array([[ 0.08135077,  0.07159284,  0.04370072, ...,  0.10575077,
#          -0.03814263,  0.04084801]], dtype=float32),
#  'What type of organism was named after Beyonce in 2012?': array([[ 0.09156412,  0.11179343,  0.09900043, ...,  0.02445458,
#          -0.03814263,  0.01684381]], dtype=float32),
#  "Which of Beyonce's songs was called Greatest Song of the 2000s?": array([[ 0.0783371 ,  0.07781803,  0.04358814, ...,  0.06717804,
#          -0.03814263,  0.05835981]], dtype=float32),
#  'How many copies did Crazy in Love sell?': array([[ 0.07842777,  0.04889802,  0.00634644, ...,  0.02911103,
#          -0.03814263,  0.05007794]], dtype=float32),
#  'Which publication considers Crazy in Love to be one of the top 500 songs of all time?': array([[ 0.09623355,  0.10003961,  0.08901216, ...,  0.09790598,
#          -0.03814263,  0.02947401]], dtype=float32),
#  'What did Bryan Lessard name after Beyoncé?': array([[ 0.04748623,  0.05739703,  0.05322549, ...,  0.04134779,
#          -0.03814263,  0.18085961]], dtype=float32),
#  ...}

# %%
# with open('data/dict_embeddings1.pickle', 'wb') as handle:
#     pickle.dump(d1, handle)

# %%
# with open('data/dict_embeddings2.pickle', 'wb') as handle:
#     pickle.dump(d2, handle)
